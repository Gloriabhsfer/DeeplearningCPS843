# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
import numpy as np
import os
import sys
import json
import pandas as pd
import random

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
from datasetTrain import DatasetTrain
# Out:
# Using TensorFlow backend.

# %%
from datasetVal import DatasetVal

# %%
from util import dec_print_val

# %%
from subprocess import call

# %%
load_saver = False
test_mode = False

learning_rate = 0.001
num_epoches = 100
batch_size = 256
num_display_steps = 15
num_saver_epoches = 1
save_dir = 'save_model/'
log_dir = 'logs/'
output_filename = 'final_output.txt'
data_dir = 'data'
test_dir = 'data/test'

# %%
special_tokens  = {'<PAD>': 0, '<BOS>': 1, '<EOS>': 2, '<UNK>': 3}
phases = {'train': 0, 'val': 1, 'test': 2}
random.seed(0)
np.random.seed(0)
tf.set_random_seed(0)
n_inputs = 4096
n_hidden = 256
val_batch_size = 100
n_frames = 80
max_caption_len = 50
forget_bias_red = 1.0
forget_bias_gre = 1.0
dropout_prob = 0.5
n_attention = n_hidden

# %%
class vedio2text:
    def __init__(self, vocab_num = 0, with_attention=True, lr = learning_rate):

        self.vocab_num = vocab_num
        self.learning_rate = lr
        self.saver = None
        self.with_attention = with_attention

    def set_saver(self, saver):
        self.saver = saver
     
    def build_model(self, feat, captions=None, cap_len=None, sampling=None, phase=0):

        weights = {
            'W_feat': tf.Variable( tf.random_uniform([n_inputs, n_hidden], -0.1, 0.1), name='W_feat'), 
            'W_dec': tf.Variable(tf.random_uniform([n_hidden, self.vocab_num], -0.1, 0.1), name='W_dec')
        }
        biases = {
            'b_feat':  tf.Variable( tf.zeros([n_hidden]), name='b_feat'),
            'b_dec': tf.Variable(tf.zeros([self.vocab_num]), name='b_dec')
        }   
        embeddings = {
         'emb': tf.Variable(tf.random_uniform([self.vocab_num, n_hidden], -0.1, 0.1), name='emb')
        }
        if self.with_attention:
            print('wrapped with bahdanau_attention...')
            weights['w_enc_out'] =  tf.Variable(tf.random_uniform([n_hidden, n_hidden]), 
                dtype=tf.float32, name='w_enc_out')
            weights['w_dec_state'] =  tf.Variable(tf.random_uniform([n_hidden, n_hidden]), 
                dtype=tf.float32, name='w_dec_state')
            weights['v'] = tf.Variable(tf.random_uniform([n_hidden, 1]), 
                dtype=tf.float32, name='v')

        batch_size = tf.shape(feat)[0]

        if phase != phases['test']:
            cap_mask = tf.sequence_mask(cap_len, max_caption_len, dtype=tf.float32)
     
        if phase == phases['train']: #  add noise
            noise = tf.random_uniform(tf.shape(feat), -0.1, 0.1, dtype=tf.float32)
            feat = feat + noise

        if phase == phases['train']:
            feat = tf.nn.dropout(feat, dropout_prob)

        feat = tf.reshape(feat, [-1, n_inputs])
        image_emb = tf.matmul(feat, weights['W_feat']) + biases['b_feat']
        image_emb = tf.reshape(image_emb, [-1, n_frames, n_hidden])
        image_emb = tf.transpose(image_emb, perm=[1, 0, 2])
        
        with tf.variable_scope('LSTM1'):
            lstm_red = tf.nn.rnn_cell.BasicLSTMCell(n_hidden, forget_bias=forget_bias_red, state_is_tuple=True)
            if phase == phases['train']:
                lstm_red = tf.contrib.rnn.DropoutWrapper(lstm_red, output_keep_prob=dropout_prob)    
        with tf.variable_scope('LSTM2'):
            lstm_gre = tf.nn.rnn_cell.BasicLSTMCell(n_hidden, forget_bias=forget_bias_gre, state_is_tuple=True)
            if phase == phases['train']:
                lstm_gre = tf.contrib.rnn.DropoutWrapper(lstm_gre, output_keep_prob=dropout_prob)    

        state_red = lstm_red.zero_state(batch_size, dtype=tf.float32)
        state_gre = lstm_gre.zero_state(batch_size, dtype=tf.float32)
        if self.with_attention:
            padding = tf.zeros([batch_size, n_hidden + n_attention])
        else:
            padding = tf.zeros([batch_size, n_hidden])
        #padding = tf.zeros([batch_size, n_hidden])
        h_src = []
        
        for i in range(0, n_frames):
            with tf.variable_scope("LSTM1"):
                output_red, state_red = lstm_red(image_emb[i,:,:], state_red)
            
            with tf.variable_scope("LSTM2"):
                output_gre, state_gre = lstm_gre(tf.concat([padding, output_red], axis=1), state_gre)
                h_src.append(output_gre) # even though padding is augmented, output_gre/state_gre's shape not change

        h_src = tf.stack(h_src, axis = 0)

        bos = tf.ones([batch_size, n_hidden])
        padding_in = tf.zeros([batch_size, n_hidden])

        logits = []
        max_prob_index = None
        if self.with_attention:
            def bahdanau_attention(time, prev_output=None):
                
                if time == 0:
                    H_t = h_src[-1,:, :] # encoder last output as first target input, H_t
                else:
                    H_t = prev_output

                H_t = tf.matmul(H_t, weights['w_dec_state'])
                H_s = tf.identity(h_src) # copy
                    
                H_s = tf.reshape(H_s, (-1, n_hidden))
                score = tf.matmul(H_s, weights['w_enc_out'])
                score = tf.reshape(score, (-1, batch_size, n_hidden))
                score = tf.add(score, tf.expand_dims(H_t, 0))
                
                score = tf.reshape(score, (-1, n_hidden))
                score = tf.matmul(tf.tanh(score), weights['v'])
                score = tf.reshape(score, (n_frames, batch_size, 1))
                score = tf.nn.softmax(score, dim=-1, name='alpha')

                H_s = tf.reshape(H_s, (-1, batch_size, n_hidden))
                C_i = tf.reduce_sum(tf.multiply(H_s, score), axis=0)
                return C_i


            def luong_attention(time, prev_output=None):
                
                if time == 0:
                    H_t = h_src[-1,:, :] # encoder last output as first target input, H_t
                else:
                    H_t = prev_output
                H_s = tf.identity(h_src) # copy

                H_s = tf.reshape(H_s, (-1, n_hidden))
                score = tf.matmul(H_s, weights['w_enc_out'])

                H_s = tf.reshape(H_s, (-1, batch_size, n_hidden))
                score = tf.reshape(score, (-1, batch_size, n_hidden))
                
                score = tf.reduce_sum(tf.multiply(score, tf.expand_dims(H_t, 0)), axis=-1)
                score = tf.nn.softmax(score, dim=-1, name='alpha')

                C_i = tf.reduce_sum(tf.multiply(H_s, tf.expand_dims(score, 2)), axis=0)
                return C_i

        cross_ent_list = []
        
        for i in range(0, max_caption_len):

            with tf.variable_scope("LSTM1"):
                output_red, state_red = lstm_red(padding_in, state_red)

            if i == 0:
                with tf.variable_scope("LSTM2"):
                    con = tf.concat([bos, output_red], axis=1)
                    if self.with_attention:
                        C_i = bahdanau_attention(i)
                        #C_i = luong_attention(i)
                        con = tf.concat([con, C_i], axis=1)
                    output_gre, state_gre = lstm_gre(con, state_gre)
            else:
                if phase == phases['train']:
                    if sampling[i] == True:
                        feed_in = captions[:, i - 1]
                    else:
                        feed_in = tf.argmax(logit_words, 1)
                else:
                    feed_in = tf.argmax(logit_words, 1)
                with tf.device("/cpu:0"):
                    embed_result = tf.nn.embedding_lookup(embeddings['emb'], feed_in)
                with tf.variable_scope("LSTM2"):
                    con = tf.concat([embed_result, output_red], axis=1)
                    if self.with_attention:
                        C_i = bahdanau_attention(i, state_gre[1]) # (state_c, state_h)
                        #C_i = luong_attention(i, state_gre[1])
                        con = tf.concat([con, C_i], axis=1)
                    output_gre, state_gre = lstm_gre(con, state_gre)
            logit_words = tf.matmul(output_gre, weights['W_dec']) + biases['b_dec']
            logits.append(logit_words)

            if phase != phases['test']:
                labels = captions[:, i]
                one_hot_labels = tf.one_hot(labels, self.vocab_num, on_value = 1, off_value = None, axis = 1) 
                cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=logit_words, labels=one_hot_labels)
                cross_entropy = cross_entropy * cap_mask[:, i]
                cross_ent_list.append(cross_entropy)
        
        loss = 0.0
        if phase != phases['test']:
            cross_entropy_tensor = tf.stack(cross_ent_list, 1)
            loss = tf.reduce_sum(cross_entropy_tensor, axis=1)
            loss = tf.divide(loss, tf.cast(cap_len, tf.float32))
            loss = tf.reduce_mean(loss, axis=0)

        logits = tf.stack(logits, axis = 0)
        logits = tf.reshape(logits, (max_caption_len, batch_size, self.vocab_num))
        logits = tf.transpose(logits, [1, 0, 2])
        
        summary = None
        if phase == phases['train']:
            summary = tf.summary.scalar('training loss', loss)
        elif phase == phases['val']:
            summary = tf.summary.scalar('validation loss', loss)

        return logits, loss, summary

    def inference(self, logits):
        
        dec_pred = tf.argmax(logits, 2)
        return dec_pred

    def optimize(self, loss_op):

        params = tf.trainable_variables()
        optimizer = tf.train.AdamOptimizer(self.learning_rate)#.minimize(loss_op)
        gradients, variables = zip(*optimizer.compute_gradients(loss_op))
        gradients, _ = tf.clip_by_global_norm(gradients, 5.0)
        train_op = optimizer.apply_gradients(zip(gradients, params))
        return train_op

# %%
def train():
    datasetTrain = DatasetTrain(data_dir, batch_size)
    datasetTrain.build_train_data_obj_list()
    vocab_num = datasetTrain.dump_tokenizer()
    datasetVal = DatasetVal(data_dir, val_batch_size)
    datasetVal.build_val_data_obj_list()
    _ = datasetVal.load_tokenizer() # vocab_num are the same

    train_graph = tf.Graph()
    val_graph = tf.Graph()

    with train_graph.as_default():
        feat = tf.placeholder(tf.float32, [None, n_frames, n_inputs])
        captions = tf.placeholder(tf.int32, [None, max_caption_len])
        sampling = tf.placeholder(tf.bool, [max_caption_len])
        cap_len = tf.placeholder(tf.int32, [None])
        model = vedio2text(vocab_num=vocab_num, with_attention=True,
                    lr=learning_rate)
        logits, loss_op, summary = model.build_model(feat, captions, cap_len, sampling, phases['train'])
        dec_pred = model.inference(logits)
        train_op = model.optimize(loss_op)

        model.set_saver(tf.train.Saver(max_to_keep = 3))
        init = tf.global_variables_initializer()
    train_sess = tf.Session(graph=train_graph)

    with val_graph.as_default():
        feat_val = tf.placeholder(tf.float32, [None, n_frames, n_inputs])
        captions_val = tf.placeholder(tf.int32, [None, max_caption_len])
        cap_len_val = tf.placeholder(tf.int32, [None])

        model_val = vedio2text(vocab_num=vocab_num,with_attention=True,lr=learning_rate)
        logits_val, loss_op_val, summary_val = model_val.build_model(feat_val, 
                    captions_val, cap_len_val, phase=phases['val'])
        dec_pred_val = model_val.inference(logits_val)

        model_val.set_saver(tf.train.Saver(max_to_keep=3))
    val_sess = tf.Session(graph=val_graph)

    load = load_saver
    if not load:
        train_sess.run(init)
    else:
        saver_path = save_dir
        latest_checkpoint = tf.train.latest_checkpoint(saver_path)
        model.saver.restore(train_sess, latest_checkpoint)

    ckpts_path = save_dir + "save_net.ckpt"
    summary_writer = tf.summary.FileWriter(log_dir + '/train')
    summary_writer.add_graph(train_graph)
    summary_writer.add_graph(val_graph)

    samp_prob = 0.6    
    for epo in range(num_epoches):
        datasetTrain.shuffle_perm()
        num_steps = int( datasetTrain.batch_max_size / batch_size )
        epo_loss = 0
        for i in range(0, num_steps):
            data_batch, label_batch, caption_lens_batch, id_batch = datasetTrain.next_batch()
            samp = datasetTrain.schedule_sampling(samp_prob, caption_lens_batch)
            if i % num_display_steps == 1:
                # training 
                run_options = tf.RunOptions(trace_level=tf.RunOptions.FULL_TRACE)
                _, loss, p, summ = train_sess.run([train_op, loss_op, dec_pred, summary], 
                                feed_dict={feat: data_batch,
                                           captions: label_batch,
                                           cap_len: caption_lens_batch,
                                           sampling: samp},
                                options=run_options)
                summary_writer.add_summary(summ, global_step=(epo * num_steps) + i)
                print("\n Training Epoch " + str(epo)  + ",......")

            else:
                _, loss, p = train_sess.run([train_op, loss_op, dec_pred], 
                                feed_dict={feat: data_batch,
                                           captions: label_batch,
                                           cap_len: caption_lens_batch,
                                           sampling: samp})
            epo_loss += loss
        av_loss = epo_loss/num_steps
        print("\n Finished Epoch " + str(epo) + \
                ", (Training Loss (avarage loss in this epoch): " + "{:.4f}".format(av_loss) + ")")

        if epo % num_saver_epoches == 0:
            ckpt_path = model.saver.save(train_sess, ckpts_path, 
                global_step=(epo * num_steps) + num_steps - 1)
            # validation
            model_val.saver.restore(val_sess, ckpt_path)
            print("\n Validating Epoch " + str(epo) +  ",......")
            
            num_steps_val = int( datasetVal.batch_max_size / val_batch_size )
            total_loss_val = 0
            txt = open('output.txt', 'w')
            for j in range(0, num_steps_val):

                data_batch, label_batch, caption_lens_batch, id_batch = datasetVal.next_batch()
                loss_val, p_val, summ = val_sess.run([loss_op_val, dec_pred_val, summary_val], 
                                        feed_dict={feat_val: data_batch,
                                                   captions_val: label_batch,
                                                   cap_len_val: caption_lens_batch})
                seq = dec_print_val(p_val, caption_lens_batch, 
                    label_batch, datasetVal.idx_to_word, val_batch_size, id_batch)
                total_loss_val += loss_val
                summary_writer.add_summary(summ, global_step=(epo * num_steps_val) + j)
                for k in range(0, val_batch_size):
                    txt.write(id_batch[k] + "," + seq[k] + "\n")
            
            #print('\nSave file: ' + FLAGS.output_filename)
            txt.close()
            call(['python3', 'bleu_eval.py', 'output.txt'])
                
            print("Validation: " + str((j+1) * val_batch_size) + "/" + \
                    str(datasetVal.batch_max_size) + ", done..." \
                    + "Total Loss: " + "{:.4f}".format(total_loss_val))
    print('\n\nTraining finished!')

# %%
def main(_):
    train()

# %%
if __name__ == '__main__':
    tf.app.run(main=main)
# Out:
# [Training] total data size: 24232
# [Validation] total data size: 100
# wrapped with bahdanau_attention...
# wrapped with bahdanau_attention...
#
#  Training Epoch 0,......
#
#  Training Epoch 0,......
#
#  Training Epoch 0,......
#
#  Training Epoch 0,......
#
#  Training Epoch 0,......
#
#  Training Epoch 0,......
#
#  Training Epoch 0,......
#
#  Finished Epoch 0, (Training Loss (avarage loss in this epoch): 5.1865)
#
#  Validating Epoch 0,......
#
# id: 6JnGBs88sL0_4_10.avi
# answer: ['a', 'helicopter', 'is', 'landing', 'on', 'a', '<UNK>']
# prediction: ['a', 'a', 'a', 'a']
#
# id: EpMuCrbxE8A_107_115.avi
# answer: ['the', 'rock', '<UNK>', 'played', 'his', 'guitar']
# prediction: ['a', 'a', 'a', 'a']
#
# id: HAjwXjwN9-A_16_24.avi
# answer: ['women', 'with', 'numbers', 'on', 'their', 'backs', 'are', 'skating', 'in', 'a', 'roller', '<UNK>']
# prediction: ['a', 'a', 'a', 'a']
#
# id: 8MVo7fje_oE_125_130.avi
# answer: ['a', 'man', 'puts', 'a', 'lid', 'on', 'a', 'plastic', 'container']
# prediction: ['a', 'a', 'a', 'a']
#
# id: 7NNg0_n-bS8_21_30.avi
# answer: ['a', 'man', 'is', 'singing', 'and', 'playing', 'a', 'guitar']
# prediction: ['a', 'a', 'a', 'a']
#
# id: MrQd1zUVRUM_103_110.avi
# answer: ['two', 'girls', 'kiss']
# prediction: ['a', 'a', 'a', 'a']
#
# id: YmXCfQm0_CA_277_284.avi
# answer: ['a', 'snake', 'is', '<UNK>', 'through', 'some', 'leaves']
# prediction: ['a', 'a', 'a', 'a']
#
# id: TZ860P4iTaM_15_28.avi
# answer: ['a', 'cat', 'plays', 'the', 'piano']
# prediction: ['a', 'a', 'a', 'a']
#
# id: u4T76jsPin0_0_11.avi
# answer: ['a', 'group', 'of', 'men', 'are', 'racing', 'down', 'a', 'track']
# prediction: ['a', 'a', 'a', 'a']
#
# id: WTf5EgVY5uU_124_128.avi
# answer: ['a', 'woman', 'is', 'buttering', 'garlic', 'in', 'a', 'pan']
# prediction: ['a', 'a', 'a']
# Validation: 100/100, done...Total Loss: 4.5433
#
#  Training Epoch 1,......
#
#  Training Epoch 1,......
#
#  Training Epoch 1,......
#
#  Training Epoch 1,......
#
#  Training Epoch 1,......
#
#  Training Epoch 1,......
#
#  Training Epoch 1,......
#
#  Finished Epoch 1, (Training Loss (avarage loss in this epoch): 4.6648)
#
#  Validating Epoch 1,......
#
# id: tJHUH9tpqPg_113_118.avi
# answer: ['a', 'woman', 'is', '<UNK>', 'a', 'lemon']
# prediction: ['a', 'is', 'is', 'is']
#
# id: 4PcL6-mjRNk_11_18.avi
# answer: ['a', 'dog', 'runs', 'down', 'a', 'hallway', 'with', 'a', 'tennis', 'ball', 'in', 'his', 'mouth']
# prediction: ['a', 'is', 'is', 'is']
#
# id: RZL9irxnhZ0_34_40.avi
# answer: ['a', 'man', 'is', 'being', '<UNK>', 'by', 'the', '<UNK>']
# prediction: ['a', 'is', 'is', 'is']
#
# id: WWf0Z6ak3Dg_5_15.avi
# answer: ['the', 'dog', 'is', 'playing', 'with', 'a', 'ball']
# prediction: ['a', 'a', 'is', 'is']
#
# id: klteYv1Uv9A_27_33.avi
# answer: ['a', 'man', 'is', 'riding', 'a', 'motorcycle']
# prediction: ['a', 'man', 'is', 'is']
#
# id: 77iDIp40m9E_126_131.avi
# answer: ['a', 'dog', 'is', 'riding', 'a', 'skateboard']
# prediction: ['a', 'a', 'is', 'is']
#
# id: zulPFoY64wE_26_33.avi
# answer: ['a', 'man', 'is', 'riding', 'a', 'horse', 'by', 'a', '<UNK>']
# prediction: ['a', 'man', 'is', 'is']
#
# id: MrQd1zUVRUM_103_110.avi
# answer: ['two', 'young', 'women', 'are', 'kissing']
# prediction: ['a', 'man', 'is', 'is']
#
# id: NUYu9c9XsgY_7_21.avi
# answer: ['a', 'man', 'is', 'typing']
# prediction: ['a', 'is', 'is', 'is']
#
# id: sJSmRik2c-c_1_7.avi
# answer: ['the', 'train', 'went', 'by', 'the', '<UNK>']
# prediction: ['a', 'man', 'is', 'is']
# Validation: 100/100, done...Total Loss: 4.3415
#
#  Training Epoch 2,......
#
#  Training Epoch 2,......
#
#  Training Epoch 2,......
#
#  Training Epoch 2,......
#
#  Training Epoch 2,......
#
#  Training Epoch 2,......
#
#  Training Epoch 2,......
#
#  Finished Epoch 2, (Training Loss (avarage loss in this epoch): 4.4432)
#
#  Validating Epoch 2,......
#
# id: tJHUH9tpqPg_113_118.avi
# answer: ['a', 'woman', 'is', 'squeezing', 'a', 'lemon']
# prediction: ['a', 'is', 'is', 'is']
#
# id: n016q1w8Q30_2_11.avi
# answer: ['a', 'person', '<UNK>', 'a', 'deck', 'of', 'playing', 'cards']
# prediction: ['a', 'is', 'is', 'is']
#
# id: 6JnGBs88sL0_4_10.avi
# answer: ['a', 'helicopter', 'is', 'landing']
# prediction: ['a', 'man', 'is', 'is']
#
# id: 778mkceE0UQ_40_46.avi
# answer: ['a', 'car', 'is', 'moving', 'through', 'a', 'road']
# prediction: ['a', 'man', 'is', 'a']
#
# id: 04Gt01vatkk_248_265.avi
# answer: ['a', 'girl', 'is', 'cutting', 'onion', 'into', 'small', 'pieces']
# prediction: ['a', 'is', 'is', 'is']
#
# id: DhwrBs96Kgk_120_124.avi
# answer: ['a', 'monkey', 'walking', '<UNK>', 'a', 'shallow', 'body', 'of', 'water']
# prediction: ['a', 'man', 'is', 'a']
#
# id: qeKX-N1nKiM_0_5.avi
# answer: ['someone', 'poured', 'soy', 'sauce', 'on', 'the', 'plate', 'of', 'food']
# prediction: ['a', 'is', 'is', 'is']
#
# id: qvg9eM4Hmzk_4_10.avi
# answer: ['the', 'man', 'lifted', 'the', 'truck', 'up', 'and', 'down', 'by', 'its', 'bed']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: YmXCfQm0_CA_277_284.avi
# answer: ['a', 'snake', 'is', '<UNK>', 'through', 'some', 'leaves']
# prediction: ['a', 'is', 'is', 'is']
#
# id: j2Dhf-xFUxU_13_20.avi
# answer: ['a', 'person', 'is', 'slicing', '<UNK>', 'into', 'pieces']
# prediction: ['a', 'is', 'is', 'is']
# Validation: 100/100, done...Total Loss: 4.1029
#
#  Training Epoch 3,......
#
#  Training Epoch 3,......
#
#  Training Epoch 3,......
#
#  Training Epoch 3,......
#
#  Training Epoch 3,......
#
#  Training Epoch 3,......
#
#  Training Epoch 3,......
#
#  Finished Epoch 3, (Training Loss (avarage loss in this epoch): 4.2818)
#
#  Validating Epoch 3,......
#
# id: XOAgUVVwKEA_8_20.avi
# answer: ['a', 'toddler', 'is', 'eating', 'spaghetti', 'in', 'a', 'high', 'chair']
# prediction: ['a', 'is', 'is', 'is', 'a']
#
# id: xCFCXzDUGjY_5_9.avi
# answer: ['a', 'skateboarder', '<UNK>', 'his', 'landing', 'and', 'crashes']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 7NNg0_n-bS8_21_30.avi
# answer: ['the', 'man', 'is', 'singing', 'and', 'playing', 'the', 'guitar']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 77iDIp40m9E_126_131.avi
# answer: ['a', 'dog', 'is', 'riding', 'a', 'skateboard']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: DhwrBs96Kgk_120_124.avi
# answer: ['an', 'animal', 'walks', 'on', 'its', 'hind', 'legs', 'through', 'a', '<UNK>', 'area']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: qeKX-N1nKiM_0_5.avi
# answer: ['someone', 'is', 'pouring', 'sauce', 'on', 'a', '<UNK>', 'of', 'food']
# prediction: ['a', 'woman', 'is', 'is', 'a']
#
# id: jbzaMtPYtl8_48_58.avi
# answer: ['two', 'men', 'are', 'pushing', 'large', '<UNK>']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: qvg9eM4Hmzk_4_10.avi
# answer: ['a', 'man', 'is', 'lifting', 'up', 'a', 'car']
# prediction: ['a', 'man', 'is', 'a', 'a', 'a']
#
# id: inzk2fTUe1w_1_15.avi
# answer: ['a', 'person', 'opening', 'a', 'banana']
# prediction: ['a', 'man', 'is', 'is']
#
# id: sJSmRik2c-c_1_7.avi
# answer: ['a', 'train', 'goes', 'by']
# prediction: ['a', 'man', 'is', 'a', 'a', 'a']
# Validation: 100/100, done...Total Loss: 4.1209
#
#  Training Epoch 4,......
#
#  Training Epoch 4,......
#
#  Training Epoch 4,......
#
#  Training Epoch 4,......
#
#  Training Epoch 4,......
#
#  Training Epoch 4,......
#
#  Training Epoch 4,......
#
#  Finished Epoch 4, (Training Loss (avarage loss in this epoch): 4.1642)
#
#  Validating Epoch 4,......
#
# id: ufFT2BWh3BQ_0_8.avi
# answer: ['two', 'baby', 'pandas', 'are', 'playing']
# prediction: ['a', 'cat', 'is', 'is']
#
# id: 5YJaS2Eswg0_22_26.avi
# answer: ['a', 'girl', 'is', 'jumping', 'rope']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: He7Ge7Sogrk_47_70.avi
# answer: ['the', 'elephant', 'is', 'painting']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: JntMAcTlOF0_50_70.avi
# answer: ['a', 'boy', 'is', '<UNK>', 'chased']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 7NNg0_n-bS8_21_30.avi
# answer: ['a', 'man', 'played', 'his', '<UNK>', 'on', 'stage']
# prediction: ['a', 'man', 'is', 'is', 'a']
#
# id: 71soiLO6I9U_15_24.avi
# answer: ['a', 'hedgehog', 'walks', 'into', 'its', 'house']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: g1Gldu1KS44_8_14.avi
# answer: ['a', 'baby', 'elephant', 'eats', 'a', '<UNK>']
# prediction: ['a', 'cat', 'is', 'a', 'a']
#
# id: j2Dhf-xFUxU_13_20.avi
# answer: ['a', 'man', 'is', 'cutting', 'vegetables']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: N2Cm0SLr0ZE_18_29.avi
# answer: ['a', 'little', 'boy', 'is', 'playing', 'a', 'guitar', 'and', 'singing']
# prediction: ['a', 'man', 'is', 'is', 'a']
# Validation: 100/100, done...Total Loss: 3.9292
#
#  Training Epoch 5,......
#
#  Training Epoch 5,......
#
#  Training Epoch 5,......
#
#  Training Epoch 5,......
#
#  Training Epoch 5,......
#
#  Training Epoch 5,......
#
#  Training Epoch 5,......
#
#  Finished Epoch 5, (Training Loss (avarage loss in this epoch): 4.0473)
#
#  Validating Epoch 5,......
#
# id: ScdUht-pM6s_53_63.avi
# answer: ['a', 'man', 'making', 'a', 'chicken']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: wkgGxsuNVSg_34_41.avi
# answer: ['a', 'young', 'child', 'is', 'running', 'around', 'in', 'circles', 'trying', 'to', '<UNK>', 'the', 'fish', 'on', 'the', '<UNK>', 'he', 'is', 'holding', 'when', 'he', 'drops', 'the', 'pole', 'and', 'runs', 'off']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: XOAgUVVwKEA_8_20.avi
# answer: ['a', 'baby', 'eats', 'spaghetti', 'with', 'her', 'hands']
# prediction: ['a', 'is', 'is', 'is', 'a']
#
# id: UbmZAe5u5FI_132_141.avi
# answer: ['the', 'woman', 'is', 'removing', 'the', 'skin', 'and', '<UNK>', 'of', 'the', 'fish']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: bqMmyY1ImkI_0_14.avi
# answer: ['three', 'boys', 'are', 'playing', 'in', 'an', 'inflatable', 'swimming', 'pool']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 77iDIp40m9E_126_131.avi
# answer: ['a', 'dog', 'is', 'skating', 'on', 'road']
# prediction: ['a', 'is', 'is', 'a', 'a', 'a']
#
# id: DhwrBs96Kgk_120_124.avi
# answer: ['a', 'monkey', 'is', 'wading', 'across', 'a', '<UNK>']
# prediction: ['a', 'man', 'is', 'a', 'a', 'a']
#
# id: 71soiLO6I9U_15_24.avi
# answer: ['an', 'animal', 'is', '<UNK>']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: lo4KcsBN--A_0_10.avi
# answer: ['the', 'turtle', 'is', 'walking', 'under', 'water']
# prediction: ['a', 'is', 'is', 'a', 'a']
# Validation: 100/100, done...Total Loss: 4.0038
#
#  Training Epoch 6,......
#
#  Training Epoch 6,......
#
#  Training Epoch 6,......
#
#  Training Epoch 6,......
#
#  Training Epoch 6,......
#
#  Training Epoch 6,......
#
#  Training Epoch 6,......
#
#  Finished Epoch 6, (Training Loss (avarage loss in this epoch): 3.9244)
#
#  Validating Epoch 6,......
#
# id: k06Ge9ANKM8_5_16.avi
# answer: ['the', 'dog', 'enjoyed', '<UNK>', '<UNK>']
# prediction: ['a', 'are', 'are', 'playing']
#
# id: lw7pTwpx0K0_38_48.avi
# answer: ['a', 'man', '<UNK>', 'a', 'wave', '<UNK>', 'on', 'the', '<UNK>', 'of', 'a', '<UNK>', 'driver']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 6q1dX6thX3E_286_295.avi
# answer: ['a', 'man', 'is', 'talking', 'on', 'the', 'phone']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: Dgf0VHMEtNs_57_66.avi
# answer: ['<UNK>', 'are', 'operating', 'a', 'man']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: f9Won2JpOEU_60_80.avi
# answer: ['a', 'cat', 'is', 'cleaning', 'itself']
# prediction: ['a', 'cat', 'is', 'a', 'a']
#
# id: qeKX-N1nKiM_0_5.avi
# answer: ['a', 'person', 'is', 'pouring', 'sauce', 'over', 'a', 'plate', 'of', 'food']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: 1Sp2__RCT0c_11_15.avi
# answer: ['a', 'burning', 'structure', 'is', '<UNK>', 'in', 'the', 'sky']
# prediction: ['a', 'is', 'is', 'a', 'a']
#
# id: xxHx6s_DbUo_216_222.avi
# answer: ['a', 'man', 'is', '<UNK>']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: N2Cm0SLr0ZE_18_29.avi
# answer: ['the', 'boy', 'is', 'singing', 'and', 'playing', 'the', 'guitar']
# prediction: ['a', 'man', 'is', 'playing', 'a']
#
# id: 7HcYJKMxpcg_20_28.avi
# answer: ['a', 'lion', 'is', 'walking']
# prediction: ['a', 'man', 'is', 'a', 'a', 'a']
# Validation: 100/100, done...Total Loss: 3.7551
#
#  Training Epoch 7,......
#
#  Training Epoch 7,......
#
#  Training Epoch 7,......
#
#  Training Epoch 7,......
#
#  Training Epoch 7,......
#
#  Training Epoch 7,......
#
#  Training Epoch 7,......
#
#  Finished Epoch 7, (Training Loss (avarage loss in this epoch): 3.8090)
#
#  Validating Epoch 7,......
#
# id: lw7pTwpx0K0_38_48.avi
# answer: ['the', 'man', 'demonstrated', 'the', 'car', '<UNK>']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: EpMuCrbxE8A_107_115.avi
# answer: ['a', 'man', '<UNK>', 'on', 'his', 'electric', 'guitar']
# prediction: ['a', 'man', 'is', 'playing', 'a']
#
# id: HAjwXjwN9-A_16_24.avi
# answer: ['the', 'lady', '<UNK>', 'were', 'in', 'a', 'roller', '<UNK>']
# prediction: ['two', 'are', 'are', 'are']
#
# id: 4xVGpDmA4lE_23_33.avi
# answer: ['a', 'man', 'is', 'carrying', 'a', 'woman', 'on', 'his', 'back']
# prediction: ['a', 'dog', 'is', 'a', 'a']
#
# id: IhwPQL9dFYc_124_129.avi
# answer: ['a', 'woman', 'in', 'slicing', 'through', 'a', 'block', 'of', 'tofu']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: BAf3LXFUaGs_28_38.avi
# answer: ['someone', 'is', 'playing', 'drums']
# prediction: ['a', 'man', 'is', 'playing', 'a']
#
# id: e-j59PqJjSM_405_416.avi
# answer: ['a', 'person', 'is', 'mixing', 'food', 'in', 'a', 'bowl']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: f9Won2JpOEU_60_80.avi
# answer: ['a', 'cat', 'is', 'licking', 'its', 'paw']
# prediction: ['a', 'cat', 'is', 'a', 'a']
#
# id: pW9DFPqoIsI_26_50.avi
# answer: ['the', 'man', '<UNK>', 'headphones']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: u4T76jsPin0_0_11.avi
# answer: ['the', 'racers', '<UNK>', 'across', 'the', 'finish', 'line']
# prediction: ['a', 'are', 'are', 'playing']
# Validation: 100/100, done...Total Loss: 3.8400
#
#  Training Epoch 8,......
#
#  Training Epoch 8,......
#
#  Training Epoch 8,......
#
#  Training Epoch 8,......
#
#  Training Epoch 8,......
#
#  Training Epoch 8,......
#
#  Training Epoch 8,......
#
#  Finished Epoch 8, (Training Loss (avarage loss in this epoch): 3.7095)
#
#  Validating Epoch 8,......
#
# id: wkgGxsuNVSg_34_41.avi
# answer: ['a', 'little', 'boy', 'has', 'a', '<UNK>', '<UNK>', 'in', 'his', 'hand', 'with', 'a', 'fish', 'on', 'the', 'end', 'of', 'the', 'line', 'and', "he's", 'running', 'around', 'in', 'a', 'circle']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: lw7pTwpx0K0_38_48.avi
# answer: ['a', 'man', 'is', 'making', '<UNK>']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: UbmZAe5u5FI_132_141.avi
# answer: ['the', 'woman', 'is', 'removing', 'the', 'skin', 'and', '<UNK>', 'of', 'the', 'fish']
# prediction: ['a', 'woman', 'is', 'slicing', 'a']
#
# id: 8MVo7fje_oE_125_130.avi
# answer: ['a', 'man', 'is', 'putting', 'lid', 'on', 'a', 'box']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: BAf3LXFUaGs_28_38.avi
# answer: ['the', 'man', 'is', 'playing', 'the', 'drums']
# prediction: ['a', 'man', 'is', 'playing', 'a']
#
# id: WWf0Z6ak3Dg_5_15.avi
# answer: ['the', 'little', 'dog', 'pushed', 'a', 'big', 'blue', 'ball']
# prediction: ['a', 'dog', 'is', 'a', 'a']
#
# id: e-j59PqJjSM_405_416.avi
# answer: ['the', 'cook', 'is', 'stirring', 'the', 'vegetables']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 0lh_UWF9ZP4_27_31.avi
# answer: ['someone', 'is', 'slicing', 'a', 'potato']
# prediction: ['a', 'woman', 'is', 'slicing', 'a']
#
# id: lo4KcsBN--A_0_10.avi
# answer: ['a', 'turtle', 'is', 'walking', 'underwater']
# prediction: ['a', 'is', 'is', 'is', 'a']
#
# id: 7HcYJKMxpcg_20_28.avi
# answer: ['a', 'lion', 'is', 'walking']
# prediction: ['a', 'dog', 'is', 'is']
# Validation: 100/100, done...Total Loss: 3.6809
#
#  Training Epoch 9,......
#
#  Training Epoch 9,......
#
#  Training Epoch 9,......
#
#  Training Epoch 9,......
#
#  Training Epoch 9,......
#
#  Training Epoch 9,......
#
#  Training Epoch 9,......
#
#  Finished Epoch 9, (Training Loss (avarage loss in this epoch): 3.6186)
#
#  Validating Epoch 9,......
#
# id: BtQtRGI0F2Q_15_20.avi
# answer: ['a', '<UNK>', '<UNK>', 'is', 'getting', 'electrical', '<UNK>', 'from', 'a', 'post']
# prediction: ['a', 'man', 'is', 'riding', 'a', 'a']
#
# id: n016q1w8Q30_2_11.avi
# answer: ['an', 'individual', '<UNK>', 'a', 'deck', 'of', 'cards']
# prediction: ['a', 'man', 'is', 'slicing', 'a']
#
# id: BAf3LXFUaGs_28_38.avi
# answer: ['a', 'guy', 'is', 'playing', 'drums']
# prediction: ['a', 'man', 'is', 'playing']
#
# id: 6q1dX6thX3E_286_295.avi
# answer: ['a', 'man', 'speaks', 'on', 'a', 'cell', 'phone']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 04Gt01vatkk_248_265.avi
# answer: ['a', 'woman', 'slices', 'an', 'onion']
# prediction: ['a', 'woman', 'is', 'applying', 'a']
#
# id: qeKX-N1nKiM_0_5.avi
# answer: ['the', 'woman', 'is', 'pouring', 'soy', 'sauce', 'over', 'the', 'dish']
# prediction: ['a', 'woman', 'is', 'adding', 'a']
#
# id: J---aiyznGQ_0_6.avi
# answer: ['a', 'cat', 'is', 'playing', 'the', 'keyboard']
# prediction: ['a', 'man', 'is', 'playing', 'a']
#
# id: pW9DFPqoIsI_26_50.avi
# answer: ['the', 'man', '<UNK>', 'headphones']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: aM-RcQj0a7I_37_55.avi
# answer: ['a', 'woman', 'is', 'frying', 'dough', 'in', 'a', 'pan']
# prediction: ['a', 'man', 'is', 'a', 'a', 'a']
#
# id: CGllPWAwmUo_1_15.avi
# answer: ['a', 'young', 'man', 'is', 'standing', 'on', 'a', 'roof', 'playing', 'a', 'fiddle']
# prediction: ['a', 'man', 'is', 'a', 'a']
# Validation: 100/100, done...Total Loss: 3.7403
#
#  Training Epoch 10,......
#
#  Training Epoch 10,......
#
#  Training Epoch 10,......
#
#  Training Epoch 10,......
#
#  Training Epoch 10,......
#
#  Training Epoch 10,......
#
#  Training Epoch 10,......
#
#  Finished Epoch 10, (Training Loss (avarage loss in this epoch): 3.5372)
#
#  Validating Epoch 10,......
#
# id: BtQtRGI0F2Q_15_20.avi
# answer: ['several', 'men', 'or', 'working', 'at', 'the', 'top', 'of', 'a', '<UNK>', 'pole', 'when', 'one', 'man', 'gets', '<UNK>', 'then', 'hangs', 'upside', 'down']
# prediction: ['a', 'man', 'is', 'riding', 'a', 'a']
#
# id: JntMAcTlOF0_50_70.avi
# answer: ['a', 'boy', 'is', 'being', 'chased', 'by', 'a', 'group', 'of', 'boys']
# prediction: ['a', 'man', 'is', 'riding', 'a']
#
# id: 778mkceE0UQ_40_46.avi
# answer: ['a', 'red', 'car', 'with', 'two', 'black', '<UNK>', 'on', 'the', '<UNK>', 'is', 'being', 'driven', 'down', 'the', 'street']
# prediction: ['a', 'car', 'is', 'a', 'a']
#
# id: qeKX-N1nKiM_0_5.avi
# answer: ['a', 'person', 'pours', 'sauce', 'onto', 'a', 'plate']
# prediction: ['a', 'person', 'is', 'a', 'a']
#
# id: MrQd1zUVRUM_103_110.avi
# answer: ['two', 'women', 'are', 'kissing']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: jbzaMtPYtl8_48_58.avi
# answer: ['two', 'men', 'are', 'pushing', 'large', '<UNK>']
# prediction: ['a', 'are', 'are', 'a', 'a']
#
# id: NUYu9c9XsgY_7_21.avi
# answer: ['a', 'person', 'is', 'typing', 'on', 'a', 'keyboard']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: cnsjm3fNEec_4_10.avi
# answer: ['a', 'man', 'stuffed', 'his', 'face', 'with', 'food']
# prediction: ['a', 'woman', 'is', 'a', 'a']
# Validation: 100/100, done...Total Loss: 3.6230
#
#  Training Epoch 11,......
#
#  Training Epoch 11,......
#
#  Training Epoch 11,......
#
#  Training Epoch 11,......
#
#  Training Epoch 11,......
#
#  Training Epoch 11,......
#
#  Training Epoch 11,......
#
#  Finished Epoch 11, (Training Loss (avarage loss in this epoch): 3.4517)
#
#  Validating Epoch 11,......
#
# id: ufFT2BWh3BQ_0_8.avi
# answer: ['two', 'baby', 'pandas', 'are', 'playing']
# prediction: ['a', 'panda', 'panda', 'is']
#
# id: EpMuCrbxE8A_107_115.avi
# answer: ['a', 'man', 'is', 'playing', '<UNK>', 'electric', 'guitar']
# prediction: ['a', 'man', 'is', 'playing', 'a']
#
# id: 7NNg0_n-bS8_21_30.avi
# answer: ['a', 'man', 'is', 'singing', 'and', 'playing', 'the', 'guitar']
# prediction: ['a', 'man', 'is', 'singing']
#
# id: 778mkceE0UQ_40_46.avi
# answer: ['a', 'person', 'is', 'driving', 'a', 'car', 'on', 'the', 'road']
# prediction: ['a', 'car', 'is', 'a', 'a', 'car']
#
# id: Cjf21Y19aUQ_82_86.avi
# answer: ['a', 'man', 'takes', 'off', 'his', 'glasses']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 5HAf_INrFy0_3_25.avi
# answer: ['a', 'cat', '<UNK>', 'a', 'boxing', 'match', 'on', 'television']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: inzk2fTUe1w_1_15.avi
# answer: ['a', 'woman', 'is', 'opening', 'a', 'banana']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: aM-RcQj0a7I_37_55.avi
# answer: ['a', 'person', 'is', 'cooking', 'something']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: TZ860P4iTaM_15_28.avi
# answer: ['a', 'cat', 'is', 'playing', 'piano']
# prediction: ['a', 'cat', 'is', 'playing', 'a']
#
# id: u4T76jsPin0_0_11.avi
# answer: ['men', 'are', 'racing']
# prediction: ['a', 'are', 'are', 'a']
# Validation: 100/100, done...Total Loss: 3.6617
#
#  Training Epoch 12,......
#
#  Training Epoch 12,......
#
#  Training Epoch 12,......
#
#  Training Epoch 12,......
#
#  Training Epoch 12,......
#
#  Training Epoch 12,......
#
#  Training Epoch 12,......
#
#  Finished Epoch 12, (Training Loss (avarage loss in this epoch): 3.3716)
#
#  Validating Epoch 12,......
#
# id: UbmZAe5u5FI_132_141.avi
# answer: ['the', 'lady', 'peeled', 'the', 'skin', 'off', 'the', 'fish']
# prediction: ['a', 'person', 'is', 'cutting', 'a']
#
# id: bqMmyY1ImkI_0_14.avi
# answer: ['three', 'boys', 'are', 'swimming', 'in', 'a', 'pool']
# prediction: ['a', 'person', 'is', 'a', 'a']
#
# id: q7pOFn8s4zc_263_273.avi
# answer: ['a', 'couple', 'slow', 'dances']
# prediction: ['a', 'man', 'is', 'dancing', 'a']
#
# id: dfOuTx66bJU_34_39.avi
# answer: ['a', 'man', 'is', 'running', 'along', 'a', 'wooded', 'path']
# prediction: ['a', 'are', 'are', 'a']
#
# id: zulPFoY64wE_26_33.avi
# answer: ['a', 'man', 'is', 'riding', 'a', 'horse', 'by', 'a', '<UNK>']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: MrQd1zUVRUM_103_110.avi
# answer: ['two', 'young', 'women', 'are', 'kissing']
# prediction: ['a', 'baby', 'is', 'is', 'a']
#
# id: jbzaMtPYtl8_48_58.avi
# answer: ['men', 'are', 'moving', '<UNK>']
# prediction: ['a', 'man', 'is', 'playing', 'a']
#
# id: s1ZABV7AQdA_38_48.avi
# answer: ['the', '<UNK>', 'chased', 'the', 'man']
# prediction: ['a', 'are', 'are', 'a']
#
# id: zv2RIbUsnSw_335_341.avi
# answer: ['the', 'woman', 'is', 'being', 'wheeled', 'into', 'the', 'hospital']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: lo4KcsBN--A_0_10.avi
# answer: ['a', 'turtle', 'walks', 'on', 'the', 'bottom', 'of', 'the', 'ocean']
# prediction: ['a', 'dog', 'is', 'is', 'a']
# Validation: 100/100, done...Total Loss: 3.6897
#
#  Training Epoch 13,......
#
#  Training Epoch 13,......
#
#  Training Epoch 13,......
#
#  Training Epoch 13,......
#
#  Training Epoch 13,......
#
#  Training Epoch 13,......
#
#  Training Epoch 13,......
#
#  Finished Epoch 13, (Training Loss (avarage loss in this epoch): 3.3054)
#
#  Validating Epoch 13,......
#
# id: f9Won2JpOEU_60_80.avi
# answer: ['a', 'cat', 'is', 'licking', 'its', 'leg']
# prediction: ['a', 'cat', 'is', 'playing', 'a']
#
# id: Je3V7U5Ctj4_569_576.avi
# answer: ['a', 'man', 'is', 'sprinkling', 'something', 'on', 'food']
# prediction: ['a', 'man', 'is', 'a', 'a', 'a']
#
# id: xxHx6s_DbUo_216_222.avi
# answer: ['a', 'man', 'is', '<UNK>']
# prediction: ['a', 'man', 'is', 'running', 'a']
#
# id: cnsjm3fNEec_4_10.avi
# answer: ['the', 'man', 'stuffed', 'his', 'face', 'with', 'food']
# prediction: ['a', 'man', 'is', 'talking', 'a']
#
# id: j2Dhf-xFUxU_13_20.avi
# answer: ['the', 'lady', 'cut', 'through', 'the', '<UNK>']
# prediction: ['a', 'woman', 'is', 'slicing', 'a']
#
# id: ZbtpcGi2DWY_161_170.avi
# answer: ['a', 'polar', 'bear', 'is', 'climbing', 'rocks']
# prediction: ['two', 'are', 'are', 'eating']
#
# id: RSx5G0_xH48_12_17.avi
# answer: ['a', 'dog', 'is', 'barking']
# prediction: ['a', 'cat', 'is', 'playing', 'a']
#
# id: WTf5EgVY5uU_124_128.avi
# answer: ['a', 'person', 'is', 'sauteing', 'garlic', 'in', 'a', 'pan']
# prediction: ['a', 'woman', 'is', 'cooking', 'a']
# Validation: 100/100, done...Total Loss: 3.7846
#
#  Training Epoch 14,......
#
#  Training Epoch 14,......
#
#  Training Epoch 14,......
#
#  Training Epoch 14,......
#
#  Training Epoch 14,......
#
#  Training Epoch 14,......
#
#  Training Epoch 14,......
#
#  Finished Epoch 14, (Training Loss (avarage loss in this epoch): 3.2339)
#
#  Validating Epoch 14,......
#
# id: UbmZAe5u5FI_132_141.avi
# answer: ['a', 'woman', 'is', 'removing', '<UNK>', 'from', 'a', 'fish']
# prediction: ['a', 'person', 'is', 'cutting', 'a']
#
# id: RjpbFlOHFps_8_25.avi
# answer: ['an', '<UNK>', 'is', '<UNK>']
# prediction: ['a', 'man', 'is', 'down', 'a']
#
# id: IhwPQL9dFYc_124_129.avi
# answer: ['the', 'lady', 'sliced', 'the', 'cheese']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: BAf3LXFUaGs_28_38.avi
# answer: ['a', 'young', 'man', 'is', 'playing', 'the', 'drums', 'while', 'two', 'women', 'are', 'playing', 'keyboards']
# prediction: ['a', 'man', 'is', 'playing', 'a']
#
# id: e-j59PqJjSM_405_416.avi
# answer: ['someone', 'is', 'mixing', 'salad', 'in', 'a', 'bowl']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: J_evFB7RIKA_104_120.avi
# answer: ['the', 'lady', 'cut', 'a', 'bell', 'pepper', 'and', '<UNK>', 'it']
# prediction: ['a', 'man', 'is', 'slicing', 'a']
#
# id: g1Gldu1KS44_8_14.avi
# answer: ['a', 'baby', 'elephant', 'is', 'eating']
# prediction: ['a', 'is', 'is', 'a']
#
# id: N2Cm0SLr0ZE_18_29.avi
# answer: ['a', 'little', 'boy', 'is', 'singing', 'and', 'playing', 'a', 'guitar']
# prediction: ['a', 'boy', 'is', 'playing', 'a']
#
# id: CGllPWAwmUo_1_15.avi
# answer: ['a', 'man', 'plays', 'a', 'violin', 'on', 'the', 'roof', 'of', 'a', 'house']
# prediction: ['a', 'man', 'is', 'a', 'a']
# Validation: 100/100, done...Total Loss: 3.6078
#
#  Training Epoch 15,......
#
#  Training Epoch 15,......
#
#  Training Epoch 15,......
#
#  Training Epoch 15,......
#
#  Training Epoch 15,......
#
#  Training Epoch 15,......
#
#  Training Epoch 15,......
#
#  Finished Epoch 15, (Training Loss (avarage loss in this epoch): 3.1725)
#
#  Validating Epoch 15,......
#
# id: shPymuahrsc_5_12.avi
# answer: ['a', 'slow', 'loris', 'is', 'looking', 'at', 'a', 'plastic', 'container']
# prediction: ['a', 'dog', 'is', 'is', 'a']
#
# id: XOAgUVVwKEA_8_20.avi
# answer: ['the', 'baby', 'is', 'eating', 'spaghetti']
# prediction: ['a', 'baby', 'is', 'is', 'a']
#
# id: JntMAcTlOF0_50_70.avi
# answer: ['a', 'boy', 'is', '<UNK>', 'chased']
# prediction: ['a', 'man', 'is', 'running', 'a']
#
# id: 6q1dX6thX3E_286_295.avi
# answer: ['a', 'man', 'speaks', 'on', 'a', 'cell', 'phone']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: qLwgb3F0aPU_298_305.avi
# answer: ['a', 'group', 'of', 'men', 'are', 'exercising']
# prediction: ['people', 'are', 'are']
#
# id: mmSQTI6gMNQ_120_128.avi
# answer: ['two', 'men', '<UNK>', 'behind', 'some', 'bushes', 'and', 'watch', 'two', 'women']
# prediction: ['two', 'women', 'are', 'dancing']
#
# id: 5HAf_INrFy0_3_25.avi
# answer: ['a', 'cat', '<UNK>', 'a', 'boxing', 'match', 'on', 'television']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: j2Dhf-xFUxU_13_20.avi
# answer: ['the', 'lady', 'cut', 'through', 'the', '<UNK>']
# prediction: ['a', 'woman', 'is', 'slicing', 'a']
#
# id: ecm9gf2Pgkc_1_24.avi
# answer: ['a', 'woman', 'is', 'playing', 'with', 'a', 'rabbit']
# prediction: ['a', 'person', 'is', 'a', 'a']
#
# id: WTf5EgVY5uU_124_128.avi
# answer: ['a', 'woman', 'is', 'buttering', 'garlic', 'in', 'a', 'pan']
# prediction: ['a', 'man', 'is', 'cooking', 'a', 'a']
# Validation: 100/100, done...Total Loss: 3.5459
#
#  Training Epoch 16,......
#
#  Training Epoch 16,......
#
#  Training Epoch 16,......
#
#  Training Epoch 16,......
#
#  Training Epoch 16,......
#
#  Training Epoch 16,......
#
#  Training Epoch 16,......
#
#  Finished Epoch 16, (Training Loss (avarage loss in this epoch): 3.1120)
#
#  Validating Epoch 16,......
#
# id: 0lh_UWF9ZP4_62_69.avi
# answer: ['a', 'woman', 'is', 'mixing', 'ingredients', 'in', 'a', 'bowl']
# prediction: ['a', 'woman', 'is', 'mixing', 'eggs', 'a']
#
# id: klteYv1Uv9A_27_33.avi
# answer: ['a', 'man', 'laying', 'down', 'is', 'riding', 'a', 'motorcycle']
# prediction: ['a', 'woman', 'is', 'riding', 'a', 'a']
#
# id: 778mkceE0UQ_40_46.avi
# answer: ['a', 'car', 'is', 'driving', 'down', 'a', 'road']
# prediction: ['a', 'car', 'is', 'a', 'a', 'car']
#
# id: e-j59PqJjSM_50_98.avi
# answer: ['the', 'man', 'is', 'slicing', 'a', 'vegetable']
# prediction: ['a', 'man', 'is', 'slicing', 'a']
#
# id: f9Won2JpOEU_60_80.avi
# answer: ['a', 'cat', 'is', 'licking', 'its', 'hands']
# prediction: ['a', 'cat', 'is', 'playing', 'a', 'a']
#
# id: DhwrBs96Kgk_120_124.avi
# answer: ['a', 'monkey', 'is', 'wading', 'across', 'a', '<UNK>']
# prediction: ['a', 'man', 'is', 'walking', 'a', 'a']
#
# id: HV12kTtdTT4_5_14.avi
# answer: ['a', 'cat', 'is', 'watching', 'a', 'tv']
# prediction: ['a', 'man', 'is', 'playing', 'a']
#
# id: RSx5G0_xH48_12_17.avi
# answer: ['a', 'dog', 'is', 'barking']
# prediction: ['a', 'cat', 'is', 'playing', 'a', 'a']
#
# id: N2Cm0SLr0ZE_18_29.avi
# answer: ['a', 'young', 'boy', 'is', 'singing', 'while', 'playing', 'the', 'guitar']
# prediction: ['a', 'boy', 'is', 'playing', 'a']
#
# id: lo4KcsBN--A_0_10.avi
# answer: ['a', 'turtle', 'is', 'walking', 'underwater']
# prediction: ['a', 'is', 'is', 'a', 'a']
# Validation: 100/100, done...Total Loss: 3.6188
#
#  Training Epoch 17,......
#
#  Training Epoch 17,......
#
#  Training Epoch 17,......
#
#  Training Epoch 17,......
#
#  Training Epoch 17,......
#
#  Training Epoch 17,......
#
#  Training Epoch 17,......
#
#  Finished Epoch 17, (Training Loss (avarage loss in this epoch): 3.0590)
#
#  Validating Epoch 17,......
#
# id: shPymuahrsc_5_12.avi
# answer: ['a', 'slow', 'loris', 'is', 'looking', 'and', 'smelling', 'a', 'box']
# prediction: ['a', 'dog', 'is', 'eating', 'a']
#
# id: n016q1w8Q30_2_11.avi
# answer: ['someone', 'did', 'a', 'card', 'trick']
# prediction: ['a', 'person', 'is', 'slicing', 'onion']
#
# id: EpMuCrbxE8A_107_115.avi
# answer: ['a', 'man', 'is', 'playing', '<UNK>', 'electric', 'guitar']
# prediction: ['a', 'man', 'is', 'playing', 'a']
#
# id: bqMmyY1ImkI_0_14.avi
# answer: ['some', 'children', 'are', 'playing', 'in', 'a', '<UNK>', 'pool']
# prediction: ['a', 'are', 'is', 'a', 'a']
#
# id: glrijRGnmc0_211_215.avi
# answer: ['a', 'man', 'turns', 'on', 'the', 'microwave']
# prediction: ['a', 'man', 'is', 'eating', 'a', 'a']
#
# id: DhwrBs96Kgk_120_124.avi
# answer: ['a', 'small', 'monkey', 'walks', 'through', 'water']
# prediction: ['a', 'man', 'is', 'running', 'a']
#
# id: mmSQTI6gMNQ_120_128.avi
# answer: ['men', 'are', 'looking', 'woman']
# prediction: ['two', 'women', 'are', 'dancing']
#
# id: 5HAf_INrFy0_3_25.avi
# answer: ['a', 'cat', 'is', 'watching', 'a', 'boxing', 'match', 'and', '<UNK>', 'it']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: ecm9gf2Pgkc_1_24.avi
# answer: ['a', 'bunny', 'is', 'playing', 'with', 'a', 'person']
# prediction: ['a', 'cat', 'is', 'a', 'a']
# Validation: 100/100, done...Total Loss: 3.8134
#
#  Training Epoch 18,......
#
#  Training Epoch 18,......
#
#  Training Epoch 18,......
#
#  Training Epoch 18,......
#
#  Training Epoch 18,......
#
#  Training Epoch 18,......
#
#  Training Epoch 18,......
#
#  Finished Epoch 18, (Training Loss (avarage loss in this epoch): 3.0091)
#
#  Validating Epoch 18,......
#
# id: tJHUH9tpqPg_113_118.avi
# answer: ['a', 'woman', 'is', 'squeezing', 'juice', 'out', 'of', 'a', 'lemon']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: 8MVo7fje_oE_125_130.avi
# answer: ['a', 'man', 'is', 'putting', 'the', 'lid', 'onto', 'a', 'container']
# prediction: ['a', 'man', 'is', 'pouring', 'a', 'a']
#
# id: f9Won2JpOEU_60_80.avi
# answer: ['the', 'cat', 'gave', 'himself', 'a', 'bath']
# prediction: ['a', 'cat', 'is', 'playing', 'a', 'a']
#
# id: xxHx6s_DbUo_216_222.avi
# answer: ['a', 'man', 'is', '<UNK>']
# prediction: ['a', 'man', 'is', 'running', 'a']
#
# id: Cjf21Y19aUQ_82_86.avi
# answer: ['the', 'man', 'took', 'off', 'his', 'sunglasses', 'while', 'talking']
# prediction: ['a', 'man', 'is', 'playing', 'a', 'a']
#
# id: inzk2fTUe1w_1_15.avi
# answer: ['the', 'person', 'is', 'peeling', 'a', 'banana']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: RSx5G0_xH48_12_17.avi
# answer: ['a', 'puppy', 'is', 'barking']
# prediction: ['a', 'cat', 'is', 'playing', 'playing', 'a']
#
# id: ecm9gf2Pgkc_1_24.avi
# answer: ['a', 'girl', 'playing', 'with', 'a', 'white', 'puppy']
# prediction: ['a', 'cat', 'is', 'a', 'a']
#
# id: zv2RIbUsnSw_335_341.avi
# answer: ['a', 'woman', 'on', 'a', 'gurney', 'is', 'being', 'pushed', 'into', 'a', 'room']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 7HcYJKMxpcg_20_28.avi
# answer: ['a', 'lion', 'is', 'walking', 'around', 'his', 'pen']
# prediction: ['a', 'are', 'is', 'running', 'running']
# Validation: 100/100, done...Total Loss: 3.5128
#
#  Training Epoch 19,......
#
#  Training Epoch 19,......
#
#  Training Epoch 19,......
#
#  Training Epoch 19,......
#
#  Training Epoch 19,......
#
#  Training Epoch 19,......
#
#  Training Epoch 19,......
#
#  Finished Epoch 19, (Training Loss (avarage loss in this epoch): 2.9604)
#
#  Validating Epoch 19,......
#
# id: 5YJaS2Eswg0_22_26.avi
# answer: ['a', 'girl', 'is', 'jumping', 'rope', 'in', 'the', 'road']
# prediction: ['a', 'man', 'is', 'a', 'a', 'a']
#
# id: n016q1w8Q30_2_11.avi
# answer: ['someone', 'did', 'a', 'card', 'trick']
# prediction: ['a', 'person', 'is', 'slicing', 'onion']
#
# id: 6JnGBs88sL0_4_10.avi
# answer: ['a', 'helicopter', 'is', 'landing']
# prediction: ['a', 'plane', 'is', 'a', 'a']
#
# id: UdcObAQ5OOM_15_30.avi
# answer: ['a', 'girl', 'is', 'talking', 'on', 'the', 'phone']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: klteYv1Uv9A_27_33.avi
# answer: ['a', 'man', 'is', 'lying', 'back', 'on', 'a', 'moving', 'motorcycle']
# prediction: ['a', 'man', 'is', 'riding', 'a', 'a']
#
# id: f9Won2JpOEU_60_80.avi
# answer: ['the', 'cat', 'is', 'cleaning', 'himself']
# prediction: ['a', 'cat', 'is', 'playing', 'a', 'a']
#
# id: rl1rVk_xIOs_1_16.avi
# answer: ['kids', 'are', 'dancing']
# prediction: ['two', 'are', 'are', 'fighting']
#
# id: 0lh_UWF9ZP4_27_31.avi
# answer: ['the', 'lady', 'chopped', 'up', 'the', 'vegetable']
# prediction: ['a', 'woman', 'is', 'slicing', 'a']
#
# id: 88DOMJ11q2M_84_87.avi
# answer: ['a', 'cartoon', 'woman', 'dives', 'off', 'of', 'a', 'diving', 'board', 'into', 'a', 'swimming', 'pool']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: g1Gldu1KS44_8_14.avi
# answer: ['a', 'baby', 'elephant', 'is', 'eating', 'leaves']
# prediction: ['a', 'elephant', 'is', 'eating']
# Validation: 100/100, done...Total Loss: 3.6840
#
#  Training Epoch 20,......
#
#  Training Epoch 20,......
#
#  Training Epoch 20,......
#
#  Training Epoch 20,......
#
#  Training Epoch 20,......
#
#  Training Epoch 20,......
#
#  Training Epoch 20,......
#
#  Finished Epoch 20, (Training Loss (avarage loss in this epoch): 2.9143)
#
#  Validating Epoch 20,......
#
# id: He7Ge7Sogrk_47_70.avi
# answer: ['an', 'elephant', 'is', 'painting']
# prediction: ['a', 'is', 'is', 'a', 'a']
#
# id: tJHUH9tpqPg_113_118.avi
# answer: ['a', 'person', 'squeezes', 'a', 'lemon']
# prediction: ['a', 'girl', 'is', 'a', 'a']
#
# id: HAjwXjwN9-A_16_24.avi
# answer: ['girls', 'are', 'skating', 'in', 'a', 'race']
# prediction: ['two', 'men', 'are', 'playing']
#
# id: 778mkceE0UQ_40_46.avi
# answer: ['a', 'red', 'car', 'with', 'two', 'black', '<UNK>', 'on', 'the', '<UNK>', 'is', 'being', 'driven', 'down', 'the', 'street']
# prediction: ['a', 'car', 'is', 'driving', 'a', 'car']
#
# id: DhwrBs96Kgk_120_124.avi
# answer: ['a', 'monkey', 'is', 'walking', 'through', 'the', 'water']
# prediction: ['a', 'man', 'is', 'running', 'a']
#
# id: UXs3eq68ZjE_250_255.avi
# answer: ['a', 'person', 'is', 'adding', 'rice', 'to', '<UNK>']
# prediction: ['a', 'is', 'is', 'stirring', 'rice']
#
# id: 5HAf_INrFy0_3_25.avi
# answer: ['a', 'cat', 'is', 'watching', 'a', 'boxing', 'match', 'and', '<UNK>', 'it']
# prediction: ['a', 'woman', 'is', 'is']
#
# id: j2Dhf-xFUxU_13_20.avi
# answer: ['someone', 'is', 'cutting', 'a', 'stack', 'of', '<UNK>']
# prediction: ['a', 'woman', 'is', 'a', 'a']
# Validation: 100/100, done...Total Loss: 3.6640
#
#  Training Epoch 21,......
#
#  Training Epoch 21,......
#
#  Training Epoch 21,......
#
#  Training Epoch 21,......
#
#  Training Epoch 21,......
#
#  Training Epoch 21,......
#
#  Training Epoch 21,......
#
#  Finished Epoch 21, (Training Loss (avarage loss in this epoch): 2.8755)
#
#  Validating Epoch 21,......
#
# id: sZf3VDsdDPM_107_114.avi
# answer: ['a', 'man', 'and', 'woman', 'are', 'eating']
# prediction: ['a', 'woman', 'is', 'talking', 'a']
#
# id: 4PcL6-mjRNk_11_18.avi
# answer: ['a', 'dog', '<UNK>', 'his', 'ball', 'to', 'a', 'machine']
# prediction: ['a', 'dog', 'is', 'a', 'a', 'a']
#
# id: 04Gt01vatkk_248_265.avi
# answer: ['a', 'woman', 'cuts', 'an', '<UNK>']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: rl1rVk_xIOs_1_16.avi
# answer: ['a', 'toddler', 'dances', 'with', 'a', 'group', 'of', 'kids']
# prediction: ['two', 'are', 'are', 'playing']
#
# id: 30GeJHYoerk_121_126.avi
# answer: ['a', 'man', 'is', 'jumping', 'with', 'his', 'hands', 'on', 'the', 'ground']
# prediction: ['a', 'boy', 'is', 'down', 'a']
#
# id: UXs3eq68ZjE_250_255.avi
# answer: ['a', 'person', 'is', 'pouring', 'rice', 'into', 'a', 'pot', 'of', 'water']
# prediction: ['someone', 'person', 'is', 'stirring', 'a']
#
# id: j2Dhf-xFUxU_13_20.avi
# answer: ['someone', 'is', 'slicing', 'something']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: ecm9gf2Pgkc_1_24.avi
# answer: ['a', 'girl', 'is', 'playing', 'with', 'a', 'rabbit']
# prediction: ['a', 'cat', 'is', 'a', 'a']
# Validation: 100/100, done...Total Loss: 3.5705
#
#  Training Epoch 22,......
#
#  Training Epoch 22,......
#
#  Training Epoch 22,......
#
#  Training Epoch 22,......
#
#  Training Epoch 22,......
#
#  Training Epoch 22,......
#
#  Training Epoch 22,......
#
#  Finished Epoch 22, (Training Loss (avarage loss in this epoch): 2.8359)
#
#  Validating Epoch 22,......
#
# id: k06Ge9ANKM8_5_16.avi
# answer: ['a', 'dog', 'is', 'playing', 'with', '<UNK>']
# prediction: ['a', 'are', 'are', 'are', 'a']
#
# id: shPymuahrsc_5_12.avi
# answer: ['a', 'slow', 'loris', 'is', 'looking', 'and', 'smelling', 'a', 'box']
# prediction: ['a', 'dog', 'is', 'is', 'a', 'a']
#
# id: 6q1dX6thX3E_286_295.avi
# answer: ['the', 'man', 'talked', 'on', 'the', 'telephone']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 77iDIp40m9E_126_131.avi
# answer: ['a', 'dog', 'is', 'riding', 'a', 'skateboard', 'on', 'the', 'road']
# prediction: ['a', 'man', 'is', 'riding', 'a', 'a']
#
# id: e-j59PqJjSM_50_98.avi
# answer: ['a', 'man', 'is', 'cutting', 'up', 'a', 'cucumber']
# prediction: ['a', 'man', 'is', 'slicing', 'an', 'onion']
#
# id: qvg9eM4Hmzk_4_10.avi
# answer: ['a', 'man', 'is', 'picking', 'up', 'a', 'truck']
# prediction: ['a', 'man', 'is', 'lifting', 'a']
#
# id: 5HAf_INrFy0_3_25.avi
# answer: ['a', 'cat', 'is', 'watching', 'wrestling', 'on', 'television']
# prediction: ['a', 'woman', 'is', 'is']
#
# id: N3A7944_UJw_63_70.avi
# answer: ['a', 'man', 'is', 'tossing', '<UNK>', 'in', 'a', 'pan', 'and', '<UNK>', 'it', 'using', 'a', 'wooden', 'spatula']
# prediction: ['a', 'man', 'is', 'a', 'a', 'a']
#
# id: tcxhOGyrCtI_15_21.avi
# answer: ['a', 'cat', 'is', 'walking', 'through', 'the', 'grass']
# prediction: ['a', 'cat', 'is', 'playing', 'a', 'a']
# Validation: 100/100, done...Total Loss: 3.6614
#
#  Training Epoch 23,......
#
#  Training Epoch 23,......
#
#  Training Epoch 23,......
#
#  Training Epoch 23,......
#
#  Training Epoch 23,......
#
#  Training Epoch 23,......
#
#  Training Epoch 23,......
#
#  Finished Epoch 23, (Training Loss (avarage loss in this epoch): 2.8100)
#
#  Validating Epoch 23,......
#
# id: k06Ge9ANKM8_5_16.avi
# answer: ['a', 'dog', 'is', '<UNK>', '<UNK>']
# prediction: ['a', 'baby', 'are', 'playing']
#
# id: jTnrm338_KY_34_42.avi
# answer: ['the', 'pet', 'store', '<UNK>', 'put', 'the', '<UNK>', 'into', 'the', 'box']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 0lh_UWF9ZP4_62_69.avi
# answer: ['someone', 'is', 'mixing', 'ingrediants']
# prediction: ['a', 'woman', 'is', 'adding', 'eggs']
#
# id: IhwPQL9dFYc_124_129.avi
# answer: ['a', 'woman', 'with', 'a', 'knife', 'is', 'horizontally', 'slicing', 'a', 'block', 'of', 'tofu']
# prediction: ['a', 'woman', 'is', 'cutting', 'a']
#
# id: HV12kTtdTT4_5_14.avi
# answer: ['a', 'cat', 'is', 'watching', 'a', 'video']
# prediction: ['a', 'boy', 'is', 'is']
#
# id: zulPFoY64wE_26_33.avi
# answer: ['a', 'man', 'is', 'riding', 'a', 'horse']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 8HB7ywgJuTg_131_142.avi
# answer: ['a', 'person', 'is', 'frying', 'some', 'food']
# prediction: ['a', 'woman', 'is', 'frying', 'a']
#
# id: TZ860P4iTaM_15_28.avi
# answer: ['a', 'cat', 'plays', 'the', 'piano']
# prediction: ['a', 'cat', 'is', 'playing', 'a']
#
# id: lo4KcsBN--A_0_10.avi
# answer: ['the', 'turtle', 'followed', 'the', 'fish']
# prediction: ['a', 'bird', 'is', 'out']
#
# id: CGllPWAwmUo_1_15.avi
# answer: ['a', 'man', 'is', 'playing', 'the', 'violin', 'on', 'top', 'of', 'a', 'house']
# prediction: ['a', 'man', 'is', 'doing', 'a']
# Validation: 100/100, done...Total Loss: 3.6932
#
#  Training Epoch 24,......
#
#  Training Epoch 24,......
#
#  Training Epoch 24,......
#
#  Training Epoch 24,......
#
#  Training Epoch 24,......
#
#  Training Epoch 24,......
#
#  Training Epoch 24,......
#
#  Finished Epoch 24, (Training Loss (avarage loss in this epoch): 2.7727)
#
#  Validating Epoch 24,......
#
# id: BtQtRGI0F2Q_15_20.avi
# answer: ['two', 'people', 'are', 'working', 'on', 'a', 'power', 'line', 'and', 'one', 'of', 'them', 'is', '<UNK>']
# prediction: ['a', 'man', 'is', 'riding', 'a', 'a']
#
# id: RZL9irxnhZ0_34_40.avi
# answer: ['a', 'man', 'is', 'giving', 'an', 'interview']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 04Gt01vatkk_308_321.avi
# answer: ['a', 'woman', 'is', 'dicing', 'peppers']
# prediction: ['a', 'woman', 'is', 'cutting', 'a']
#
# id: xxHx6s_DbUo_216_222.avi
# answer: ['a', 'man', 'is', '<UNK>']
# prediction: ['a', 'man', 'is', 'is', 'a']
#
# id: qvg9eM4Hmzk_4_10.avi
# answer: ['a', 'man', 'lifts', 'the', 'rear', 'end', 'of', 'a', 'truck']
# prediction: ['a', 'man', 'is', 'lifting', 'a']
#
# id: cnsjm3fNEec_4_10.avi
# answer: ['a', 'man', 'is', 'eating', 'noodles', 'and', 'ice', '<UNK>']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: tcxhOGyrCtI_15_21.avi
# answer: ['a', 'cat', 'walks', 'toward', 'the', 'camera']
# prediction: ['a', 'cat', 'is', 'playing', 'a', 'a']
#
# id: inzk2fTUe1w_1_15.avi
# answer: ['someone', 'is', 'peeling', 'a', 'banana']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: ecm9gf2Pgkc_1_24.avi
# answer: ['a', 'rabbit', 'is', 'being', 'petted']
# prediction: ['a', 'cat', 'is', 'a', 'a']
#
# id: N2Cm0SLr0ZE_18_29.avi
# answer: ['a', 'child', 'is', 'playing', 'a', 'guitar']
# prediction: ['a', 'boy', 'is', 'playing', 'a']
# Validation: 100/100, done...Total Loss: 3.7516
#
#  Training Epoch 25,......
#
#  Training Epoch 25,......
#
#  Training Epoch 25,......
#
#  Training Epoch 25,......
#
#  Training Epoch 25,......
#
#  Training Epoch 25,......
#
#  Training Epoch 25,......
#
#  Finished Epoch 25, (Training Loss (avarage loss in this epoch): 2.7465)
#
#  Validating Epoch 25,......
#
# id: 5YJaS2Eswg0_22_26.avi
# answer: ['a', 'girl', 'is', 'jumping', 'rope']
# prediction: ['a', 'girl', 'is', 'riding', 'a', 'a']
#
# id: HAjwXjwN9-A_16_24.avi
# answer: ['girls', 'are', 'skating', 'in', 'a', 'race']
# prediction: ['two', 'men', 'are', 'fighting']
#
# id: mtrCf667KDk_134_176.avi
# answer: ['a', 'woman', 'is', 'peeling', 'a', '<UNK>', 'with', 'a', 'knife']
# prediction: ['a', 'woman', 'is', 'slicing', 'onion']
#
# id: IhwPQL9dFYc_124_129.avi
# answer: ['a', 'woman', 'slices', 'a', 'block', 'of', 'tofu']
# prediction: ['a', 'woman', 'is', 'cutting', 'tofu']
#
# id: qeKX-N1nKiM_0_5.avi
# answer: ['someone', 'is', '<UNK>', 'a', 'brown', 'sauce', 'into', 'a', 'bowl', 'of', 'cooked', 'meat', 'and', 'vegetables']
# prediction: ['a', 'man', 'is', 'adding', 'a']
#
# id: 0lh_UWF9ZP4_27_31.avi
# answer: ['a', 'woman', 'is', 'slicing', 'ginger']
# prediction: ['a', 'woman', 'is', 'slicing', 'onion', 'onion']
#
# id: xxHx6s_DbUo_216_222.avi
# answer: ['a', 'man', 'is', 'seated', 'in', 'a', 'garden', 'with', 'his', 'eyes', 'closed', 'as', 'he', '<UNK>', '<UNK>', '<UNK>']
# prediction: ['a', 'man', 'is', 'down']
#
# id: Cjf21Y19aUQ_82_86.avi
# answer: ['a', 'man', 'talks']
# prediction: ['a', 'man', 'is', 'playing', 'a']
#
# id: YmXCfQm0_CA_277_284.avi
# answer: ['a', 'snake', 'is', 'crawling', 'through', 'some', 'leaves']
# prediction: ['a', 'person', 'is', 'a', 'a']
#
# id: u4T76jsPin0_0_11.avi
# answer: ['a', 'group', 'of', 'men', 'are', 'racing', 'down', 'a', 'track']
# prediction: ['a', 'are', 'are']
# Validation: 100/100, done...Total Loss: 3.7775
#
#  Training Epoch 26,......
#
#  Training Epoch 26,......
#
#  Training Epoch 26,......
#
#  Training Epoch 26,......
#
#  Training Epoch 26,......
#
#  Training Epoch 26,......
#
#  Training Epoch 26,......
#
#  Finished Epoch 26, (Training Loss (avarage loss in this epoch): 2.7231)
#
#  Validating Epoch 26,......
#
# id: shPymuahrsc_5_12.avi
# answer: ['the', 'mammal', 'sniffed', 'at', 'the', 'bowl', 'of', 'food']
# prediction: ['a', 'dog', 'is', 'walking', 'on', 'a']
#
# id: tJHUH9tpqPg_113_118.avi
# answer: ['a', 'woman', 'is', '<UNK>', 'a', 'lemon']
# prediction: ['a', 'girl', 'is', 'a', 'a']
#
# id: 8MVo7fje_oE_125_130.avi
# answer: ['a', 'man', 'puts', 'a', 'lid', 'on', 'a', 'plastic', 'container']
# prediction: ['a', 'man', 'is', 'pouring', 'pasta']
#
# id: WWf0Z6ak3Dg_5_15.avi
# answer: ['a', 'dog', 'is', 'playing', 'with', 'a', 'very', 'large', 'ball']
# prediction: ['a', 'man', 'is', 'running', 'a', 'a']
#
# id: 1Sp2__RCT0c_11_15.avi
# answer: ['a', 'missile', 'falls', 'from', 'the', 'sky', 'catching', 'fire']
# prediction: ['a', 'person', 'is', 'a', 'a', 'a']
#
# id: Je3V7U5Ctj4_569_576.avi
# answer: ['a', 'person', 'is', 'spreading', 'cheese', 'on', 'a', 'tortilla']
# prediction: ['a', 'man', 'is', 'pouring', 'a', 'a', 'a']
#
# id: ecm9gf2Pgkc_1_24.avi
# answer: ['a', 'rabbit', 'is', 'being', 'petted']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: 7HcYJKMxpcg_20_28.avi
# answer: ['a', 'lion', 'is', 'walking']
# prediction: ['a', 'turtle', 'is', 'running', 'down']
# Validation: 100/100, done...Total Loss: 3.6663
#
#  Training Epoch 27,......
#
#  Training Epoch 27,......
#
#  Training Epoch 27,......
#
#  Training Epoch 27,......
#
#  Training Epoch 27,......
#
#  Training Epoch 27,......
#
#  Training Epoch 27,......
#
#  Finished Epoch 27, (Training Loss (avarage loss in this epoch): 2.7022)
#
#  Validating Epoch 27,......
#
# id: UbmZAe5u5FI_132_141.avi
# answer: ['a', 'woman', 'is', 'removing', 'fish', 'skin', 'and', '<UNK>', 'with', 'her', 'fingers']
# prediction: ['a', 'person', 'is', 'a']
#
# id: He7Ge7Sogrk_47_70.avi
# answer: ['an', 'elephant', 'is', 'painting', 'a', 'picture']
# prediction: ['a', 'dog', 'is', 'a', 'a', 'a']
#
# id: 6JnGBs88sL0_4_10.avi
# answer: ['a', 'helicopter', 'is', 'landing']
# prediction: ['a', 'plane', 'is', 'on', 'a']
#
# id: q7pOFn8s4zc_263_273.avi
# answer: ['a', 'man', 'and', 'woman', 'are', 'dancing']
# prediction: ['a', 'man', 'is', 'a', 'a', 'a']
#
# id: mtrCf667KDk_134_176.avi
# answer: ['a', 'woman', 'is', 'peeling', 'a', '<UNK>', 'with', 'a', 'knife']
# prediction: ['a', 'woman', 'is', 'slicing', 'a']
#
# id: 6q1dX6thX3E_286_295.avi
# answer: ['a', 'man', 'talks', 'on', 'a', 'telephone']
# prediction: ['a', 'man', 'is', 'is', 'a']
#
# id: Je3V7U5Ctj4_569_576.avi
# answer: ['the', 'man', 'sprinkled', 'cheese', 'on', 'the', '<UNK>']
# prediction: ['a', 'man', 'is', 'pouring', 'a']
#
# id: YmXCfQm0_CA_277_284.avi
# answer: ['the', 'snake', 'moved', 'through', 'the', 'leaves']
# prediction: ['a', 'person', 'is', 'a', 'a']
#
# id: NUYu9c9XsgY_7_21.avi
# answer: ['a', 'person', 'is', 'typing', 'on', 'a', 'keyboard']
# prediction: ['a', 'person', 'is', 'a', 'a']
#
# id: j2Dhf-xFUxU_13_20.avi
# answer: ['a', 'person', 'is', 'slicing', 'a', 'stack', 'of', '<UNK>']
# prediction: ['a', 'man', 'is', 'cutting', 'a']
# Validation: 100/100, done...Total Loss: 3.6625
#
#  Training Epoch 28,......
#
#  Training Epoch 28,......
#
#  Training Epoch 28,......
#
#  Training Epoch 28,......
#
#  Training Epoch 28,......
#
#  Training Epoch 28,......
#
#  Training Epoch 28,......
#
#  Finished Epoch 28, (Training Loss (avarage loss in this epoch): 2.6801)
#
#  Validating Epoch 28,......
#
# id: ufFT2BWh3BQ_0_8.avi
# answer: ['the', 'baby', 'pandas', 'are', 'playing']
# prediction: ['a', 'panda', 'panda', 'is', 'on']
#
# id: xCFCXzDUGjY_5_9.avi
# answer: ['a', 'skateboarder', '<UNK>', 'his', 'landing', 'and', 'crashes']
# prediction: ['a', 'man', 'is', 'a', 'a', 'a']
#
# id: 4xVGpDmA4lE_23_33.avi
# answer: ['the', 'man', 'carried', 'the', 'woman', 'and', 'the', '<UNK>', 'along', 'the', 'path']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: k5OKBX2e7xA_19_32.avi
# answer: ['the', 'man', 'is', 'doing', 'motorcycle', 'tricks']
# prediction: ['a', 'woman', 'is', 'riding', 'a']
#
# id: IhwPQL9dFYc_124_129.avi
# answer: ['a', 'woman', 'is', 'slicing', 'tofu']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: PeUHy0A1GF0_114_121.avi
# answer: ['a', 'chef', 'is', 'peeling', 'shrimp']
# prediction: ['a', 'woman', 'is', 'peeling', 'shrimp', 'shrimp']
#
# id: jbzaMtPYtl8_48_58.avi
# answer: ['men', 'are', 'pushing', 'large', '<UNK>']
# prediction: ['a', 'man', 'is', 'doing', 'a']
#
# id: 8HB7ywgJuTg_131_142.avi
# answer: ['someone', 'seasons', 'rice', 'in', 'a', 'skillet', 'with', 'a', 'white', 'substance', 'and', 'another', 'person', 'stirs', 'the', 'mixture', 'with', 'a', 'spatula']
# prediction: ['a', 'woman', 'is', 'cooking', 'shrimp']
#
# id: ZbtpcGi2DWY_161_170.avi
# answer: ['the', 'polar', 'bear', 'came', 'down', 'the', '<UNK>']
# prediction: ['two', 'bears', 'are', 'are']
#
# id: RSx5G0_xH48_12_17.avi
# answer: ['the', 'little', 'dog', 'sat', 'and', 'barked']
# prediction: ['a', 'puppy', 'is', 'playing', 'with', 'a', 'ball']
# Validation: 100/100, done...Total Loss: 3.9482
#
#  Training Epoch 29,......
#
#  Training Epoch 29,......
#
#  Training Epoch 29,......
#
#  Training Epoch 29,......
#
#  Training Epoch 29,......
#
#  Training Epoch 29,......
#
#  Training Epoch 29,......
#
#  Finished Epoch 29, (Training Loss (avarage loss in this epoch): 2.6599)
#
#  Validating Epoch 29,......
#
# ...
#
# id: ecm9gf2Pgkc_1_24.avi
# answer: ['a', 'bunny', 'is', 'playing', 'with', 'a', 'person']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: zv2RIbUsnSw_335_341.avi
# answer: ['a', 'woman', 'on', 'a', 'gurney', 'is', 'wheeled', 'into', 'the', 'hospital']
# prediction: ['a', 'man', 'is', 'is', 'a', 'a']
#
# id: CGllPWAwmUo_1_15.avi
# answer: ['a', 'man', 'is', 'playing', 'a', 'violin', 'on', 'a', 'roof']
# prediction: ['a', 'man', 'is', 'doing']
# Validation: 100/100, done...Total Loss: 4.0753
#
#  Training Epoch 91,......
#
#  Training Epoch 91,......
#
#  Training Epoch 91,......
#
#  Training Epoch 91,......
#
#  Training Epoch 91,......
#
#  Training Epoch 91,......
#
#  Training Epoch 91,......
#
#  Finished Epoch 91, (Training Loss (avarage loss in this epoch): 2.2701)
#
#  Validating Epoch 91,......
#
# id: wkgGxsuNVSg_34_41.avi
# answer: ['a', '<UNK>', 'is', 'chasing', 'a', 'boy']
# prediction: ['a', 'man', 'is', 'running', 'a', 'a']
#
# id: He7Ge7Sogrk_47_70.avi
# answer: ['the', 'elephant', 'is', 'painting']
# prediction: ['a', 'cat', 'is', 'a', 'a', 'a']
#
# id: mtrCf667KDk_134_176.avi
# answer: ['a', 'woman', 'is', 'peeling', 'a', '<UNK>']
# prediction: ['a', 'woman', 'is', 'cutting', 'a']
#
# id: klteYv1Uv9A_27_33.avi
# answer: ['a', 'man', '<UNK>', 'and', 'talks', 'on', 'a', 'phone', 'while', '<UNK>']
# prediction: ['a', 'man', 'is', 'riding', 'a', 'a']
#
# id: UXs3eq68ZjE_250_255.avi
# answer: ['someone', 'is', 'pouring', 'rice', 'into', 'rice', '<UNK>']
# prediction: ['a', 'person', 'is', 'pouring', 'into', 'a', 'a']
#
# id: qvg9eM4Hmzk_4_10.avi
# answer: ['a', 'man', 'is', 'lifting', 'the', 'back', 'of', 'a', 'truck', 'and', 'sitting', 'it', 'down']
# prediction: ['a', 'man', 'is', 'lifting', 'a', 'truck']
#
# id: N3A7944_UJw_63_70.avi
# answer: ['the', 'man', 'is', 'cooking', 'on', 'a', 'tv', 'show']
# prediction: ['a', 'man', 'is', 'a', 'a', 'a']
#
# id: j2Dhf-xFUxU_13_20.avi
# answer: ['a', 'person', 'is', 'slicing', '<UNK>', 'into', 'pieces']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: RSx5G0_xH48_12_17.avi
# answer: ['a', 'dog', 'is', 'barking']
# prediction: ['a', 'puppy', 'is', 'playing', 'a', 'a']
#
# id: ecm9gf2Pgkc_1_24.avi
# answer: ['a', 'rabbit', 'is', 'being', 'played', 'with']
# prediction: ['a', 'cat', 'is', 'a', 'a', 'a']
# Validation: 100/100, done...Total Loss: 4.1276
#
#  Training Epoch 92,......
#
#  Training Epoch 92,......
#
#  Training Epoch 92,......
#
#  Training Epoch 92,......
#
#  Training Epoch 92,......
#
#  Training Epoch 92,......
#
#  Training Epoch 92,......
#
#  Finished Epoch 92, (Training Loss (avarage loss in this epoch): 2.2687)
#
#  Validating Epoch 92,......
#
# id: wkgGxsuNVSg_34_41.avi
# answer: ['a', 'kid', 'is', 'playing', 'with', 'a', 'caught', 'fish']
# prediction: ['a', 'man', 'is', 'running', 'a', 'a']
#
# id: UdcObAQ5OOM_15_30.avi
# answer: ['a', 'woman', 'is', 'talking', 'on', 'a', 'mobile', 'phone']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: 3qqEKTPxLNs_1_15.avi
# answer: ['a', 'baby', 'plays', 'with', 'a', '<UNK>']
# prediction: ['a', 'baby', 'is', 'is', 'a', 'a']
#
# id: 7NNg0_n-bS8_21_30.avi
# answer: ['a', 'man', 'is', 'singing', 'and', 'playing', 'guitar', 'on', 'stage']
# prediction: ['a', 'man', 'is', 'dancing']
#
# id: 778mkceE0UQ_40_46.avi
# answer: ['a', 'car', 'is', 'being', 'driven', 'fast']
# prediction: ['a', 'car', 'is', 'a', 'a']
#
# id: rl1rVk_xIOs_1_16.avi
# answer: ['children', 'are', 'dancing']
# prediction: ['two', 'women', 'are', 'fighting']
#
# id: qLwgb3F0aPU_298_305.avi
# answer: ['men', 'are', 'running']
# prediction: ['men', 'are', 'are', 'are']
#
# id: J_evFB7RIKA_104_120.avi
# answer: ['a', 'person', 'is', 'slicing', 'a', 'bell', 'pepper']
# prediction: ['a', 'man', 'is', 'slicing', 'a']
#
# id: tcxhOGyrCtI_15_21.avi
# answer: ['a', 'cat', 'is', 'walking', 'slowly', 'in', 'the', 'grass']
# prediction: ['a', 'cat', 'is', 'playing', 'a', 'a']
#
# id: u4T76jsPin0_0_11.avi
# answer: ['the', 'racers', '<UNK>', 'across', 'the', 'finish', 'line']
# prediction: ['a', 'are', 'are']
# Validation: 100/100, done...Total Loss: 4.1091
#
#  Training Epoch 93,......
#
#  Training Epoch 93,......
#
#  Training Epoch 93,......
#
#  Training Epoch 93,......
#
#  Training Epoch 93,......
#
#  Training Epoch 93,......
#
#  Training Epoch 93,......
#
#  Finished Epoch 93, (Training Loss (avarage loss in this epoch): 2.2653)
#
#  Validating Epoch 93,......
#
# id: sZf3VDsdDPM_107_114.avi
# answer: ['a', 'man', 'is', 'eating', 'food']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: mtrCf667KDk_134_176.avi
# answer: ['the', 'woman', 'is', 'peeling', 'an', 'orange', 'vegetable']
# prediction: ['a', 'man', 'is', 'slicing', 'a']
#
# id: IhwPQL9dFYc_124_129.avi
# answer: ['a', 'girl', 'is', 'slicing', 'a', 'butter', 'into', 'two', 'pieces']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: PeUHy0A1GF0_114_121.avi
# answer: ['the', 'lady', 'peeled', 'the', 'shrimp']
# prediction: ['a', 'woman', 'is', 'a', 'shrimp']
#
# id: Fe4tO5vW9_E_64_70.avi
# answer: ['a', 'person', '<UNK>', 'a', 'stick', 'of', 'butter', 'in', 'a', 'pan']
# prediction: ['a', 'woman', 'is', 'adding', 'into']
#
# id: 30GeJHYoerk_121_126.avi
# answer: ['the', 'man', 'is', 'doing', 'handstand', 'tricks']
# prediction: ['a', 'are', 'are', 'a', 'a']
#
# id: N3A7944_UJw_63_70.avi
# answer: ['a', 'man', 'is', '<UNK>', 'nuts', 'in', 'a', 'pan']
# prediction: ['a', 'woman', 'is', 'a', 'a', 'a']
#
# id: J_evFB7RIKA_104_120.avi
# answer: ['a', 'person', 'is', 'slicing', 'a', 'capsicum']
# prediction: ['a', 'man', 'is', 'slicing', 'a']
# Validation: 100/100, done...Total Loss: 4.0605
#
#  Training Epoch 94,......
#
#  Training Epoch 94,......
#
#  Training Epoch 94,......
#
#  Training Epoch 94,......
#
#  Training Epoch 94,......
#
#  Training Epoch 94,......
#
#  Training Epoch 94,......
#
#  Finished Epoch 94, (Training Loss (avarage loss in this epoch): 2.2612)
#
#  Validating Epoch 94,......
#
# id: wkgGxsuNVSg_34_41.avi
# answer: ['a', 'kid', 'is', 'holding', 'a', '<UNK>', 'pole']
# prediction: ['a', 'man', 'is', 'running', 'a', 'a']
#
# id: 6JnGBs88sL0_4_10.avi
# answer: ['a', 'helicopter', 'is', 'landing', 'on', 'the', 'pad']
# prediction: ['a', 'man', 'is', 'is', 'the']
#
# id: q7pOFn8s4zc_263_273.avi
# answer: ['a', 'man', 'and', 'a', 'woman', 'dance', 'together']
# prediction: ['a', 'man', 'is', 'talking']
#
# id: mtrCf667KDk_134_176.avi
# answer: ['a', 'woman', 'is', 'peeling', 'a', '<UNK>', 'with', 'a', 'knife']
# prediction: ['a', 'man', 'is', 'peeling', 'a']
#
# id: JntMAcTlOF0_50_70.avi
# answer: ['a', 'boy', 'is', 'being', 'chased']
# prediction: ['a', 'man', 'is', 'a', 'a', 'a']
#
# id: 77iDIp40m9E_126_131.avi
# answer: ['a', 'dog', 'is', 'skateboarding', 'down', 'a', 'street']
# prediction: ['a', 'car', 'is', 'doing', 'a', 'a']
#
# id: rl1rVk_xIOs_1_16.avi
# answer: ['children', 'are', 'dancing']
# prediction: ['two', 'men', 'are', 'fighting']
#
# id: Je3V7U5Ctj4_569_576.avi
# answer: ['a', 'man', 'is', 'sprinkling', 'cheese', 'on', 'a', 'tortilla']
# prediction: ['a', 'man', 'is', 'putting', 'a', 'into', 'a']
#
# id: jbzaMtPYtl8_48_58.avi
# answer: ['two', 'men', 'are', 'rolling', 'huge', '<UNK>', '<UNK>', 'down', 'a', 'street', 'while', '<UNK>', 'watch']
# prediction: ['a', 'man', 'is', 'dancing']
#
# id: TZ860P4iTaM_15_28.avi
# answer: ['a', 'cat', 'is', 'striking', 'the', 'same', 'piano', 'keys', 'repeatedly', 'with', 'its', 'paw']
# prediction: ['a', 'cat', 'is', 'playing', 'the', 'piano']
# Validation: 100/100, done...Total Loss: 4.0243
#
#  Training Epoch 95,......
#
#  Training Epoch 95,......
#
#  Training Epoch 95,......
#
#  Training Epoch 95,......
#
#  Training Epoch 95,......
#
#  Training Epoch 95,......
#
#  Training Epoch 95,......
#
#  Finished Epoch 95, (Training Loss (avarage loss in this epoch): 2.2560)
#
#  Validating Epoch 95,......
#
# id: BtQtRGI0F2Q_15_20.avi
# answer: ['a', 'man', 'is', 'getting', '<UNK>', 'on', 'a', 'power', '<UNK>']
# prediction: ['a', 'man', 'is', 'riding', 'a', 'a']
#
# id: 0lh_UWF9ZP4_62_69.avi
# answer: ['the', 'lady', 'stirred', 'the', 'hot', 'food', 'in', 'the', 'bowl']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: DhwrBs96Kgk_120_124.avi
# answer: ['an', 'animal', 'walks', 'on', 'its', 'hind', 'legs', 'through', 'a', '<UNK>', 'area']
# prediction: ['a', 'man', 'is', 'running', 'a']
#
# id: Je3V7U5Ctj4_569_576.avi
# answer: ['a', 'person', 'sprinkles', 'shredded', 'cheese', 'on', 'a', 'tortilla']
# prediction: ['a', 'man', 'is', 'putting', 'on', 'on', 'a']
#
# id: RSx5G0_xH48_12_17.avi
# answer: ['a', 'little', 'dog', 'is', 'sitting', 'in', 'a', 'room', 'barking', 'at', 'something']
# prediction: ['a', 'cat', 'is', 'playing', 'with', 'a']
#
# id: pW9DFPqoIsI_26_50.avi
# answer: ['a', 'person', 'writing', 'opening', 'a', 'package']
# prediction: ['a', 'man', 'is', 'peeling', 'a']
#
# id: WTf5EgVY5uU_124_128.avi
# answer: ['someone', 'is', 'sauteing', 'a', 'minced', 'substance', 'in', 'a', 'wok', 'using', 'chopsticks']
# prediction: ['a', 'woman', 'is', 'cooking', 'eggs']
# Validation: 100/100, done...Total Loss: 4.2732
#
#  Training Epoch 96,......
#
#  Training Epoch 96,......
#
#  Training Epoch 96,......
#
#  Training Epoch 96,......
#
#  Training Epoch 96,......
#
#  Training Epoch 96,......
#
#  Training Epoch 96,......
#
#  Finished Epoch 96, (Training Loss (avarage loss in this epoch): 2.2577)
#
#  Validating Epoch 96,......
#
# id: tJHUH9tpqPg_113_118.avi
# answer: ['a', 'woman', 'is', 'squeezing', 'a', 'lemon']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: BAf3LXFUaGs_28_38.avi
# answer: ['a', 'man', 'plays', 'the', 'drums', 'while', 'two', 'woman', 'play', '<UNK>']
# prediction: ['a', 'man', 'is', 'playing', 'a']
#
# id: 77iDIp40m9E_126_131.avi
# answer: ['a', 'dog', 'is', 'riding', 'a', 'skateboard', 'on', 'the', 'road']
# prediction: ['a', 'car', 'is', 'riding', 'a', 'a']
#
# id: f9Won2JpOEU_60_80.avi
# answer: ['a', 'cat', 'lays', 'on', 'the', 'floor', '<UNK>', 'his', 'hand', 'across', 'his', 'face']
# prediction: ['a', 'cat', 'is', 'playing', 'a', 'cat']
#
# id: Fe4tO5vW9_E_64_70.avi
# answer: ['butter', 'is', 'being', 'melted', 'in', 'a', 'pot']
# prediction: ['a', 'is', 'is', 'a']
#
# id: 71soiLO6I9U_15_24.avi
# answer: ['an', 'animal', 'is', '<UNK>']
# prediction: ['a', 'is', 'is', 'a', 'a']
#
# id: uJPupV4oLZ0_4_12.avi
# answer: ['a', 'man', 'is', 'holding', 'a', 'very', 'tiny', 'toad', 'in', 'the', 'palm', 'of', 'his', 'hand']
# prediction: ['a', 'baby', 'is', 'eating']
#
# id: sJSmRik2c-c_1_7.avi
# answer: ['a', 'train', 'is', 'going', 'across', 'a', '<UNK>', 'track']
# prediction: ['a', 'man', 'is', 'is', 'a', 'a']
#
# id: CGllPWAwmUo_1_15.avi
# answer: ['a', 'man', 'is', 'playing', 'the', 'violin', 'on', 'a', 'roof']
# prediction: ['a', 'man', 'is', 'doing', 'a']
#
# id: WTf5EgVY5uU_124_128.avi
# answer: ['a', 'woman', 'is', 'buttering', 'garlic', 'in', 'a', 'pan']
# prediction: ['a', 'woman', 'is', 'cooking', 'a']
# Validation: 100/100, done...Total Loss: 4.0407
#
#  Training Epoch 97,......
#
#  Training Epoch 97,......
#
#  Training Epoch 97,......
#
#  Training Epoch 97,......
#
#  Training Epoch 97,......
#
#  Training Epoch 97,......
#
#  Training Epoch 97,......
#
#  Finished Epoch 97, (Training Loss (avarage loss in this epoch): 2.2576)
#
#  Validating Epoch 97,......
#
# id: xCFCXzDUGjY_5_9.avi
# answer: ['the', 'skateboarder', 'fell', 'off', 'the', 'skateboard']
# prediction: ['two', 'man', 'is', 'a', 'a']
#
# id: 4xVGpDmA4lE_23_33.avi
# answer: ['a', 'man', 'and', 'woman', 'are', 'walking', 'down', 'a', 'road']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: BAf3LXFUaGs_28_38.avi
# answer: ['someone', 'is', 'playing', 'drums']
# prediction: ['a', 'man', 'is', 'singing', 'a']
#
# id: 1Sp2__RCT0c_11_15.avi
# answer: ['the', '<UNK>', 'crashed', 'to', 'the', 'ground']
# prediction: ['a', 'person', 'is', 'a', 'a', 'a']
#
# id: MrQd1zUVRUM_103_110.avi
# answer: ['two', 'young', 'women', 'are', 'kissing']
# prediction: ['a', 'woman', 'is', 'a']
#
# id: UXs3eq68ZjE_250_255.avi
# answer: ['a', 'man', 'is', 'putting', 'rice', 'in', 'a', 'bowling', 'pot']
# prediction: ['a', 'man', 'is', 'stirring', 'rice', 'rice', 'a']
#
# id: jbzaMtPYtl8_48_58.avi
# answer: ['two', 'men', 'each', 'flip', 'a', 'huge', 'tire', 'down', 'the', 'pavement']
# prediction: ['two', 'are', 'are', 'on', 'a']
#
# id: 88DOMJ11q2M_84_87.avi
# answer: ['a', 'woman', 'jumps', 'off', 'a', 'diving', 'board', 'in', 'a', 'pool']
# prediction: ['a', 'woman', 'is', 'doing', 'a', 'a']
#
# id: sJSmRik2c-c_1_7.avi
# answer: ['a', 'yellow', 'passenger', 'train', 'is', 'speeding', 'down', 'the', 'track']
# prediction: ['a', 'man', 'is', 'is', 'a', 'a']
#
# id: lo4KcsBN--A_0_10.avi
# answer: ['a', 'sea', 'turtle', 'is', 'hunting', 'for', 'fish']
# prediction: ['a', 'bird', 'is', 'eating', 'a']
# Validation: 100/100, done...Total Loss: 4.1968
#
#  Training Epoch 98,......
#
#  Training Epoch 98,......
#
#  Training Epoch 98,......
#
#  Training Epoch 98,......
#
#  Training Epoch 98,......
#
#  Training Epoch 98,......
#
#  Training Epoch 98,......
#
#  Finished Epoch 98, (Training Loss (avarage loss in this epoch): 2.2552)
#
#  Validating Epoch 98,......
#
# id: 4xVGpDmA4lE_23_33.avi
# answer: ['a', 'man', 'carrying', 'a', '<UNK>', 'on', 'his', 'head', 'is', 'singing', 'a', 'song', 'with', 'a', 'woman', '<UNK>', 'onto', 'his', 'back', 'as', 'he', 'walks', 'by', 'the', '<UNK>']
# prediction: ['a', 'man', 'is', 'a', 'a']
#
# id: Jag7oTemldY_12_25.avi
# answer: ['a', 'man', 'makes', 'faces']
# prediction: ['a', 'man', 'is', 'a']
#
# id: UdcObAQ5OOM_15_30.avi
# answer: ['a', 'girl', 'is', 'talking', 'to', 'a', 'man', 'on', 'the', 'phone']
# prediction: ['a', 'man', 'is', 'his', 'a']
#
# id: JntMAcTlOF0_50_70.avi
# answer: ['boys', 'are', 'running', 'in', 'the', 'wood']
# prediction: ['a', 'man', 'is', 'a', 'a', 'a']
#
# id: 7NNg0_n-bS8_21_30.avi
# answer: ['a', 'man', 'seated', 'on', 'the', 'stage', 'is', 'singing', 'while', 'strumming', 'a', 'guitar']
# prediction: ['a', 'man', 'is', 'singing']
#
# id: e-j59PqJjSM_405_416.avi
# answer: ['someone', 'is', 'mixing', 'salad', 'in', 'a', 'bowl']
# prediction: ['a', 'person', 'is', 'stirring']
#
# id: UXs3eq68ZjE_250_255.avi
# answer: ['a', 'chef', 'dumps', 'rice', 'into', 'a', 'pot']
# prediction: ['a', 'person', 'is', 'stirring', 'rice']
#
# id: 8HB7ywgJuTg_131_142.avi
# answer: ['a', 'person', 'puts', 'rice', 'in', 'a', 'pan']
# prediction: ['a', 'woman', 'is', 'cooking']
#
# id: zv2RIbUsnSw_335_341.avi
# answer: ['a', 'woman', 'is', 'riding', 'on', 'a', 'hospital', 'stretcher']
# prediction: ['a', 'man', 'is', 'his', 'his', 'a']
#
# id: TZ860P4iTaM_15_28.avi
# answer: ['a', 'cat', 'is', 'playing', 'a', 'key', 'board']
# prediction: ['a', 'cat', 'is', 'playing', 'piano', 'piano']
# Validation: 100/100, done...Total Loss: 4.3634
#
#  Training Epoch 99,......
#
#  Training Epoch 99,......
#
#  Training Epoch 99,......
#
#  Training Epoch 99,......
#
#  Training Epoch 99,......
#
#  Training Epoch 99,......
#
#  Training Epoch 99,......
#
#  Finished Epoch 99, (Training Loss (avarage loss in this epoch): 2.2535)
#
#  Validating Epoch 99,......
#
# id: XOAgUVVwKEA_8_20.avi
# answer: ['the', 'girl', 'ate', 'spaghetti', 'from', 'her', 'high', 'chair']
# prediction: ['a', 'baby', 'is', 'is', 'a']
#
# id: HAjwXjwN9-A_16_24.avi
# answer: ['girls', 'are', 'skating']
# prediction: ['two', 'men', 'are', 'running']
#
# id: e-j59PqJjSM_50_98.avi
# answer: ['a', 'person', 'is', 'cutting', 'a', '<UNK>', 'of', 'a', 'cucumber']
# prediction: ['a', 'man', 'is', 'slicing', 'a']
#
# id: f9Won2JpOEU_60_80.avi
# answer: ['a', 'cat', 'is', 'washing', 'its', 'face']
# prediction: ['a', 'cat', 'is', 'playing', 'a', 'cat']
#
# id: DhwrBs96Kgk_120_124.avi
# answer: ['a', 'monkey', 'is', 'wading', 'through', 'the', 'water']
# prediction: ['a', 'man', 'is', 'running']
#
# id: 1Sp2__RCT0c_11_15.avi
# answer: ['a', '<UNK>', 'explodes', 'during', 'flight']
# prediction: ['a', 'person', 'is', 'a', 'a', 'a']
#
# id: N3A7944_UJw_63_70.avi
# answer: ['a', 'chef', 'sautes', 'food', 'in', 'a', 'large', 'pan']
# prediction: ['a', 'woman', 'is', 'a', 'a']
#
# id: N2Cm0SLr0ZE_18_29.avi
# answer: ['a', 'child', 'plays', 'the', 'guitar']
# prediction: ['a', 'boy', 'is', 'playing', 'a']
#
# id: sJSmRik2c-c_1_7.avi
# answer: ['a', 'train', 'is', 'going', 'down', 'the', 'track', 'near', 'a', 'shore']
# prediction: ['a', 'is', 'is', 'is', 'a', 'a']
# Validation: 100/100, done...Total Loss: 3.9166
#
#
# Training finished!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/yz9/.conda/envs/cpsc843/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3351: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
